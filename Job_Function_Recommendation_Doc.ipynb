# %% [markdown]
# # Mount Colab with Drive

# %% [markdown]
# Google Colaboratory is a free Jupyter notebook environment provided by Google where you can use free GPUs and TPUs. If you don’t have a computer that can take the training workload of complex machine learning and deep learning models. So [Google colab](https://colab.research.google.com/notebooks/welcome.ipynb) is a good idea for you!

# %% [markdown]
# here I will mount google colab with my drive so that it can access my drive and see my files.

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # Import Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
dataset = pd.read_csv('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/dataset/jobs_data.csv', header = 0, index_col=False)

# %% [markdown]
# # Perform EDA and Get insights about the data

# %% [markdown]
# Exploratory Data Analysis (**EDA**) is an approach to analyzing datasets to summarize their main characteristics in order to know which statistical model to use. but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.

# %%
dataset.head()
# Out:
#    Unnamed: 0  ...                                           industry
# 0           0  ...  ['Computer Software', 'Marketing and Advertisi...
# 1           1  ...                ['Information Technology Services']
# 2           2  ...       ['Computer Software', 'Computer Networking']
# 3           3  ...  ['Computer Software', 'Information Technology ...
# 4           4  ...  ['Computer Software', 'Information Technology ...
#
# [5 rows x 4 columns]

# %% [markdown]
# here we want to drop the first index column. we can use [DataFrame.drop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) function in pandas. `inplace` means to do this operation in the same dataframe.

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ##### We noticed that jobFunction has many cells with a value  of `'[nan]'`. so we want to count these nans to take a dicision to it. each cell of the jobFunction column is a string,  so I want to parse this string and converting it to NAN object.

# %%
dataset['jobFunction'].replace('[\'nan\']', np.nan, inplace=True)

# %% [markdown]
# Now we want to check the number of `nans` in the jobFunction column.
# Fortunately there exist a module in python called `Counter` can help us with this task, it will take the jobFunction series and returning a dictionary of each string with its frequency

# %%
from collections import Counter

Counter(dataset['jobFunction'])
# Out:
# Counter({"['Accounting/Finance', 'Administration', 'Operations/Management']": 1,
#          "['Accounting/Finance', 'Administration']": 8,
#          "['Accounting/Finance', 'Analyst/Research']": 9,
#          "['Accounting/Finance', 'Banking']": 1,
#          "['Accounting/Finance', 'Business Development']": 1,
#          "['Accounting/Finance', 'C-Level Executive/GM/Director']": 1,
#          "['Accounting/Finance', 'Customer Service/Support', 'IT/Software Development']": 3,
#          "['Accounting/Finance', 'Customer Service/Support']": 3,
#          "['Accounting/Finance', 'Education/Teaching']": 3,
#          "['Accounting/Finance', 'Engineering - Telecom/Technology', 'IT/Software Development']": 3,
#          "['Accounting/Finance', 'Human Resources', 'Administration']": 1,
#          "['Accounting/Finance', 'Human Resources']": 1,
#          "['Accounting/Finance', 'IT/Software Development', 'Engineering - Telecom/Technology']": 1,
#          "['Accounting/Finance', 'IT/Software Development', 'Strategy/Consulting']": 1,
#          "['Accounting/Finance', 'IT/Software Development']": 12,
#          "['Accounting/Finance', 'Logistics/Supply Chain']": 8,
#          "['Accounting/Finance', 'Operations/Management']": 5,
#          "['Accounting/Finance', 'Pharmaceutical']": 1,
#          "['Accounting/Finance', 'Project/Program Management']": 2,
#          "['Accounting/Finance', 'Quality', 'IT/Software Development']": 1,
#          "['Accounting/Finance', 'Sales/Retail']": 1,
#          "['Accounting/Finance', 'Strategy/Consulting', 'IT/Software Development']": 1,
#          "['Accounting/Finance', 'Strategy/Consulting']": 1,
#          "['Accounting/Finance']": 370,
#          "['Administration', 'Accounting/Finance']": 3,
#          "['Administration', 'Business Development', 'Operations/Management']": 1,
#          "['Administration', 'Customer Service/Support', 'Marketing/PR/Advertising']": 1,
#          "['Administration', 'Customer Service/Support', 'Medical/Healthcare']": 1,
#          "['Administration', 'Customer Service/Support', 'Operations/Management']": 2,
#          "['Administration', 'Customer Service/Support', 'Sales/Retail']": 3,
#          "['Administration', 'Customer Service/Support']": 51,
#          "['Administration', 'Education/Teaching']": 3,
#          "['Administration', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']": 1,
#          "['Administration', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Administration', 'Engineering - Telecom/Technology', 'IT/Software Development']": 1,
#          "['Administration', 'Human Resources']": 22,
#          "['Administration', 'IT/Software Development', 'Engineering - Telecom/Technology']": 1,
#          "['Administration', 'IT/Software Development']": 4,
#          "['Administration', 'Installation/Maintenance/Repair', 'Operations/Management']": 1,
#          "['Administration', 'Installation/Maintenance/Repair', 'Purchasing/Procurement']": 1,
#          "['Administration', 'Installation/Maintenance/Repair']": 2,
#          "['Administration', 'Legal', 'Accounting/Finance']": 1,
#          "['Administration', 'Legal']": 1,
#          "['Administration', 'Logistics/Supply Chain']": 1,
#          "['Administration', 'Marketing/PR/Advertising', 'Sales/Retail']": 1,
#          "['Administration', 'Marketing/PR/Advertising']": 1,
#          "['Administration', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 1,
#          "['Administration', 'Medical/Healthcare', 'Pharmaceutical']": 1,
#          "['Administration', 'Medical/Healthcare']": 3,
#          "['Administration', 'Operations/Management', 'Analyst/Research']": 1,
#          "['Administration', 'Operations/Management', 'Customer Service/Support']": 3,
#          "['Administration', 'Operations/Management', 'Hospitality/Hotels/Food Services']": 1,
#          "['Administration', 'Operations/Management', 'Marketing/PR/Advertising']": 2,
#          "['Administration', 'Operations/Management', 'Sales/Retail']": 1,
#          "['Administration', 'Operations/Management']": 13,
#          "['Administration', 'Project/Program Management', 'Engineering - Construction/Civil/Architecture']": 2,
#          "['Administration', 'Project/Program Management']": 6,
#          "['Administration', 'Purchasing/Procurement']": 12,
#          "['Administration', 'Quality']": 1,
#          "['Administration', 'Sales/Retail', 'Customer Service/Support']": 2,
#          "['Administration', 'Sales/Retail']": 9,
#          "['Administration', 'Training/Instructor']": 2,
#          "['Administration']": 395,
#          "['Analyst/Research', 'Customer Service/Support']": 2,
#          "['Analyst/Research', 'Engineering - Construction/Civil/Architecture', 'Project/Program Management']": 1,
#          "['Analyst/Research', 'Engineering - Other']": 8,
#          "['Analyst/Research', 'Engineering - Telecom/Technology', 'IT/Software Development']": 24,
#          "['Analyst/Research', 'Engineering - Telecom/Technology']": 3,
#          "['Analyst/Research', 'IT/Software Development', 'Creative/Design/Art']": 1,
#          "['Analyst/Research', 'IT/Software Development', 'Quality']": 1,
#          "['Analyst/Research', 'IT/Software Development']": 9,
#          "['Analyst/Research', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 6,
#          "['Analyst/Research', 'Marketing/PR/Advertising', 'Sales/Retail']": 1,
#          "['Analyst/Research', 'Marketing/PR/Advertising']": 4,
#          "['Analyst/Research', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 3,
#          "['Analyst/Research', 'Operations/Management', 'IT/Software Development']": 1,
#          "['Analyst/Research', 'Project/Program Management', 'IT/Software Development']": 2,
#          "['Analyst/Research', 'Project/Program Management']": 1,
#          "['Analyst/Research', 'Quality', 'IT/Software Development']": 1,
#          "['Analyst/Research', 'R&D/Science']": 1,
#          "['Analyst/Research']": 33,
#          "['Banking', 'Accounting/Finance']": 4,
#          "['Banking', 'Quality']": 2,
#          "['Business Development', 'Administration', 'Operations/Management']": 1,
#          "['Business Development', 'Analyst/Research', 'IT/Software Development']": 2,
#          "['Business Development', 'Customer Service/Support', 'IT/Software Development']": 1,
#          "['Business Development', 'Customer Service/Support', 'Marketing/PR/Advertising']": 1,
#          "['Business Development', 'Customer Service/Support', 'Sales/Retail']": 4,
#          "['Business Development', 'Customer Service/Support']": 1,
#          "['Business Development', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Business Development', 'Engineering - Telecom/Technology', 'IT/Software Development']": 1,
#          "['Business Development', 'IT/Software Development', 'Analyst/Research']": 3,
#          "['Business Development', 'IT/Software Development', 'Customer Service/Support']": 1,
#          "['Business Development', 'IT/Software Development', 'Engineering - Telecom/Technology']": 1,
#          "['Business Development', 'IT/Software Development', 'Project/Program Management']": 2,
#          "['Business Development', 'IT/Software Development', 'Sales/Retail']": 4,
#          "['Business Development', 'IT/Software Development']": 2,
#          "['Business Development', 'Installation/Maintenance/Repair', 'IT/Software Development']": 2,
#          "['Business Development', 'Marketing/PR/Advertising', 'Customer Service/Support']": 3,
#          "['Business Development', 'Marketing/PR/Advertising', 'Operations/Management']": 1,
#          "['Business Development', 'Marketing/PR/Advertising', 'Sales/Retail']": 29,
#          "['Business Development', 'Marketing/PR/Advertising']": 21,
#          "['Business Development', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 4,
#          "['Business Development', 'Medical/Healthcare', 'Marketing/PR/Advertising']": 1,
#          "['Business Development', 'Medical/Healthcare', 'Sales/Retail']": 1,
#          "['Business Development', 'Operations/Management', 'Marketing/PR/Advertising']": 1,
#          "['Business Development', 'Operations/Management', 'Sales/Retail']": 3,
#          "['Business Development', 'Project/Program Management', 'IT/Software Development']": 1,
#          "['Business Development', 'Project/Program Management', 'Sales/Retail']": 1,
#          "['Business Development', 'Project/Program Management']": 1,
#          "['Business Development', 'Sales/Retail', 'Customer Service/Support']": 13,
#          "['Business Development', 'Sales/Retail', 'IT/Software Development']": 3,
#          "['Business Development', 'Sales/Retail', 'Marketing/PR/Advertising']": 12,
#          "['Business Development', 'Sales/Retail', 'Operations/Management']": 1,
#          "['Business Development', 'Sales/Retail', 'Project/Program Management']": 1,
#          "['Business Development', 'Sales/Retail']": 53,
#          "['Business Development']": 71,
#          "['Creative/Design/Art', 'Analyst/Research', 'IT/Software Development']": 1,
#          "['Creative/Design/Art', 'Education/Teaching']": 3,
#          "['Creative/Design/Art', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']": 1,
#          "['Creative/Design/Art', 'Engineering - Construction/Civil/Architecture']": 20,
#          "['Creative/Design/Art', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']": 2,
#          "['Creative/Design/Art', 'Engineering - Mechanical/Electrical']": 3,
#          "['Creative/Design/Art', 'Engineering - Telecom/Technology', 'IT/Software Development']": 16,
#          "['Creative/Design/Art', 'Engineering - Telecom/Technology']": 2,
#          "['Creative/Design/Art', 'IT/Software Development', 'Engineering - Telecom/Technology']": 28,
#          "['Creative/Design/Art', 'IT/Software Development', 'Training/Instructor']": 1,
#          "['Creative/Design/Art', 'IT/Software Development']": 30,
#          "['Creative/Design/Art', 'Manufacturing/Production']": 2,
#          "['Creative/Design/Art', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 13,
#          "['Creative/Design/Art', 'Marketing/PR/Advertising']": 25,
#          "['Creative/Design/Art', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 4,
#          "['Creative/Design/Art', 'Media/Journalism/Publishing']": 22,
#          "['Creative/Design/Art', 'Operations/Management']": 1,
#          "['Creative/Design/Art', 'Sales/Retail', 'Marketing/PR/Advertising']": 1,
#          "['Creative/Design/Art', 'Sales/Retail']": 3,
#          "['Creative/Design/Art']": 243,
#          "['Customer Service/Support', 'Administration']": 15,
#          "['Customer Service/Support', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Customer Service/Support', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']": 2,
#          "['Customer Service/Support', 'Engineering - Mechanical/Electrical', 'Sales/Retail']": 1,
#          "['Customer Service/Support', 'Engineering - Mechanical/Electrical']": 2,
#          "['Customer Service/Support', 'Engineering - Other', 'IT/Software Development']": 1,
#          "['Customer Service/Support', 'Engineering - Telecom/Technology', 'IT/Software Development']": 8,
#          "['Customer Service/Support', 'Engineering - Telecom/Technology']": 3,
#          "['Customer Service/Support', 'IT/Software Development', 'Accounting/Finance']": 1,
#          "['Customer Service/Support', 'IT/Software Development', 'Engineering - Telecom/Technology']": 3,
#          "['Customer Service/Support', 'IT/Software Development', 'Installation/Maintenance/Repair']": 2,
#          "['Customer Service/Support', 'IT/Software Development', 'Project/Program Management']": 1,
#          "['Customer Service/Support', 'IT/Software Development', 'Sales/Retail']": 4,
#          "['Customer Service/Support', 'IT/Software Development']": 8,
#          "['Customer Service/Support', 'Installation/Maintenance/Repair', 'IT/Software Development']": 3,
#          "['Customer Service/Support', 'Logistics/Supply Chain']": 2,
#          "['Customer Service/Support', 'Marketing/PR/Advertising', 'Business Development']": 1,
#          "['Customer Service/Support', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 1,
#          "['Customer Service/Support', 'Marketing/PR/Advertising']": 8,
#          "['Customer Service/Support', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 1,
#          "['Customer Service/Support', 'Medical/Healthcare', 'Administration']": 2,
#          "['Customer Service/Support', 'Medical/Healthcare', 'Pharmaceutical']": 1,
#          "['Customer Service/Support', 'Medical/Healthcare']": 1,
#          "['Customer Service/Support', 'Operations/Management', 'Administration']": 2,
#          "['Customer Service/Support', 'Operations/Management', 'Sales/Retail']": 1,
#          "['Customer Service/Support', 'Operations/Management']": 6,
#          "['Customer Service/Support', 'Pharmaceutical', 'R&D/Science']": 1,
#          "['Customer Service/Support', 'Pharmaceutical']": 2,
#          "['Customer Service/Support', 'Sales/Retail', 'Business Development']": 1,
#          "['Customer Service/Support', 'Sales/Retail', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Customer Service/Support', 'Sales/Retail', 'Engineering - Telecom/Technology']": 1,
#          "['Customer Service/Support', 'Sales/Retail', 'Hospitality/Hotels/Food Services']": 1,
#          "['Customer Service/Support', 'Sales/Retail', 'IT/Software Development']": 2,
#          "['Customer Service/Support', 'Sales/Retail', 'Marketing/PR/Advertising']": 6,
#          "['Customer Service/Support', 'Sales/Retail', 'Medical/Healthcare']": 1,
#          "['Customer Service/Support', 'Sales/Retail', 'Strategy/Consulting']": 1,
#          "['Customer Service/Support', 'Sales/Retail', 'Tourism/Travel']": 1,
#          "['Customer Service/Support', 'Sales/Retail']": 138,
#          "['Customer Service/Support', 'Strategy/Consulting', 'Sales/Retail']": 1,
#          "['Customer Service/Support', 'Tourism/Travel']": 2,
#          "['Customer Service/Support']": 180,
#          "['Education/Teaching', 'Accounting/Finance', 'Training/Instructor']": 2,
#          "['Education/Teaching', 'Accounting/Finance']": 1,
#          "['Education/Teaching', 'Administration', 'Operations/Management']": 1,
#          "['Education/Teaching', 'Administration']": 7,
#          "['Education/Teaching', 'Analyst/Research', 'Creative/Design/Art']": 1,
#          "['Education/Teaching', 'Business Development', 'Administration']": 1,
#          "['Education/Teaching', 'Business Development', 'Operations/Management']": 1,
#          "['Education/Teaching', 'Creative/Design/Art']": 6,
#          "['Education/Teaching', 'Engineering - Mechanical/Electrical', 'Training/Instructor']": 2,
#          "['Education/Teaching', 'Engineering - Other', 'R&D/Science']": 2,
#          "['Education/Teaching', 'Engineering - Other']": 1,
#          "['Education/Teaching', 'Engineering - Telecom/Technology', 'IT/Software Development']": 2,
#          "['Education/Teaching', 'IT/Software Development', 'Engineering - Telecom/Technology']": 2,
#          "['Education/Teaching', 'IT/Software Development', 'Training/Instructor']": 1,
#          "['Education/Teaching', 'IT/Software Development']": 10,
#          "['Education/Teaching', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 1,
#          "['Education/Teaching', 'Medical/Healthcare', 'Training/Instructor']": 2,
#          "['Education/Teaching', 'Operations/Management', 'Training/Instructor']": 1,
#          "['Education/Teaching', 'Operations/Management']": 7,
#          "['Education/Teaching', 'Pharmaceutical', 'Writing/Editorial']": 1,
#          "['Education/Teaching', 'Quality']": 1,
#          "['Education/Teaching', 'R&D/Science', 'Training/Instructor']": 1,
#          "['Education/Teaching', 'R&D/Science']": 11,
#          "['Education/Teaching', 'Sports and Leisure']": 5,
#          "['Education/Teaching', 'Training/Instructor', 'R&D/Science']": 1,
#          "['Education/Teaching', 'Training/Instructor']": 62,
#          "['Education/Teaching', 'Writing/Editorial']": 6,
#          "['Education/Teaching']": 315,
#          "['Engineering - Construction/Civil/Architecture', 'Administration', 'Quality']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Administration']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Business Development']": 2,
#          "['Engineering - Construction/Civil/Architecture', 'Creative/Design/Art', 'Manufacturing/Production']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Creative/Design/Art']": 18,
#          "['Engineering - Construction/Civil/Architecture', 'Customer Service/Support']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']": 6,
#          "['Engineering - Construction/Civil/Architecture', 'Engineering - Oil & Gas/Energy', 'Sales/Retail']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Engineering - Other']": 2,
#          "['Engineering - Construction/Civil/Architecture', 'Engineering - Telecom/Technology', 'IT/Software Development']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Engineering - Telecom/Technology', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Marketing/PR/Advertising', 'Business Development']": 2,
#          "['Engineering - Construction/Civil/Architecture', 'Marketing/PR/Advertising']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Operations/Management', 'C-Level Executive/GM/Director']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Operations/Management']": 2,
#          "['Engineering - Construction/Civil/Architecture', 'Project/Program Management']": 14,
#          "['Engineering - Construction/Civil/Architecture', 'Purchasing/Procurement']": 7,
#          "['Engineering - Construction/Civil/Architecture', 'Quality']": 3,
#          "['Engineering - Construction/Civil/Architecture', 'Sales/Retail', 'Customer Service/Support']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Sales/Retail', 'Engineering - Mechanical/Electrical']": 2,
#          "['Engineering - Construction/Civil/Architecture', 'Sales/Retail', 'Project/Program Management']": 1,
#          "['Engineering - Construction/Civil/Architecture', 'Sales/Retail']": 8,
#          "['Engineering - Construction/Civil/Architecture']": 122,
#          "['Engineering - Mechanical/Electrical', 'Business Development']": 1,
#          "['Engineering - Mechanical/Electrical', 'Creative/Design/Art', 'Manufacturing/Production']": 2,
#          "['Engineering - Mechanical/Electrical', 'Creative/Design/Art']": 11,
#          "['Engineering - Mechanical/Electrical', 'Customer Service/Support', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Mechanical/Electrical', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Engineering - Mechanical/Electrical', 'Engineering - Oil & Gas/Energy', 'Sales/Retail']": 1,
#          "['Engineering - Mechanical/Electrical', 'Engineering - Other']": 2,
#          "['Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology', 'IT/Software Development']": 2,
#          "['Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']": 2,
#          "['Engineering - Mechanical/Electrical', 'IT/Software Development', 'Sales/Retail']": 1,
#          "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Customer Service/Support']": 2,
#          "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']": 1,
#          "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Manufacturing/Production']": 2,
#          "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Project/Program Management']": 1,
#          "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']": 14,
#          "['Engineering - Mechanical/Electrical', 'Logistics/Supply Chain']": 1,
#          "['Engineering - Mechanical/Electrical', 'Manufacturing/Production', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Mechanical/Electrical', 'Manufacturing/Production', 'Quality']": 2,
#          "['Engineering - Mechanical/Electrical', 'Manufacturing/Production', 'R&D/Science']": 1,
#          "['Engineering - Mechanical/Electrical', 'Manufacturing/Production']": 18,
#          "['Engineering - Mechanical/Electrical', 'Operations/Management', 'Manufacturing/Production']": 1,
#          "['Engineering - Mechanical/Electrical', 'Operations/Management']": 5,
#          "['Engineering - Mechanical/Electrical', 'Project/Program Management', 'Quality']": 1,
#          "['Engineering - Mechanical/Electrical', 'Project/Program Management']": 3,
#          "['Engineering - Mechanical/Electrical', 'Purchasing/Procurement']": 6,
#          "['Engineering - Mechanical/Electrical', 'Quality']": 2,
#          "['Engineering - Mechanical/Electrical', 'Sales/Retail', 'Engineering - Construction/Civil/Architecture']": 3,
#          "['Engineering - Mechanical/Electrical', 'Sales/Retail']": 49,
#          "['Engineering - Mechanical/Electrical']": 119,
#          "['Engineering - Oil & Gas/Energy', 'Customer Service/Support', 'Sales/Retail']": 1,
#          "['Engineering - Oil & Gas/Energy', 'Engineering - Mechanical/Electrical', 'Sales/Retail']": 1,
#          "['Engineering - Oil & Gas/Energy', 'Engineering - Other', 'Sales/Retail']": 1,
#          "['Engineering - Oil & Gas/Energy', 'Sales/Retail']": 3,
#          "['Engineering - Other', 'Analyst/Research']": 1,
#          "['Engineering - Other', 'Creative/Design/Art', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Engineering - Other', 'Creative/Design/Art']": 3,
#          "['Engineering - Other', 'Education/Teaching', 'R&D/Science']": 2,
#          "['Engineering - Other', 'Engineering - Construction/Civil/Architecture']": 5,
#          "['Engineering - Other', 'Engineering - Mechanical/Electrical']": 3,
#          "['Engineering - Other', 'IT/Software Development', 'Project/Program Management']": 1,
#          "['Engineering - Other', 'Installation/Maintenance/Repair', 'Operations/Management']": 1,
#          "['Engineering - Other', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Other', 'Manufacturing/Production']": 6,
#          "['Engineering - Other', 'Pharmaceutical', 'Quality']": 1,
#          "['Engineering - Other', 'Project/Program Management']": 1,
#          "['Engineering - Other', 'Purchasing/Procurement']": 3,
#          "['Engineering - Other', 'Quality']": 1,
#          "['Engineering - Other', 'R&D/Science', 'Medical/Healthcare']": 1,
#          "['Engineering - Other', 'R&D/Science', 'Quality']": 2,
#          "['Engineering - Other', 'R&D/Science', 'Sales/Retail']": 1,
#          "['Engineering - Other', 'R&D/Science']": 3,
#          "['Engineering - Other', 'Sales/Retail']": 7,
#          "['Engineering - Other']": 12,
#          "['Engineering - Telecom/Technology', 'Analyst/Research', 'IT/Software Development']": 9,
#          "['Engineering - Telecom/Technology', 'Creative/Design/Art', 'Engineering - Mechanical/Electrical']": 1,
#          "['Engineering - Telecom/Technology', 'Creative/Design/Art', 'IT/Software Development']": 29,
#          "['Engineering - Telecom/Technology', 'Creative/Design/Art', 'Manufacturing/Production']": 1,
#          "['Engineering - Telecom/Technology', 'Creative/Design/Art']": 1,
#          "['Engineering - Telecom/Technology', 'Customer Service/Support', 'IT/Software Development']": 18,
#          "['Engineering - Telecom/Technology', 'Customer Service/Support', 'Sales/Retail']": 1,
#          "['Engineering - Telecom/Technology', 'Customer Service/Support']": 4,
#          "['Engineering - Telecom/Technology', 'Education/Teaching', 'IT/Software Development']": 3,
#          "['Engineering - Telecom/Technology', 'Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical', 'Creative/Design/Art']": 1,
#          "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical', 'IT/Software Development']": 2,
#          "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']": 2,
#          "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical']": 6,
#          "['Engineering - Telecom/Technology', 'Engineering - Other', 'IT/Software Development']": 1,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Accounting/Finance']": 1,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Analyst/Research']": 20,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Business Development']": 1,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Creative/Design/Art']": 43,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Customer Service/Support']": 4,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Education/Teaching']": 2,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Engineering - Mechanical/Electrical']": 4,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Installation/Maintenance/Repair']": 20,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Operations/Management']": 7,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Project/Program Management']": 7,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Quality']": 18,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Sales/Retail']": 6,
#          "['Engineering - Telecom/Technology', 'IT/Software Development', 'Writing/Editorial']": 1,
#          "['Engineering - Telecom/Technology', 'IT/Software Development']": 1113,
#          "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']": 1,
#          "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair', 'IT/Software Development']": 38,
#          "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair', 'Project/Program Management']": 1,
#          "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair']": 2,
#          "['Engineering - Telecom/Technology', 'Manufacturing/Production', 'Creative/Design/Art']": 2,
#          "['Engineering - Telecom/Technology', 'Operations/Management', 'IT/Software Development']": 1,
#          "['Engineering - Telecom/Technology', 'Project/Program Management', 'IT/Software Development']": 13,
#          "['Engineering - Telecom/Technology', 'Quality', 'IT/Software Development']": 13,
#          "['Engineering - Telecom/Technology', 'R&D/Science', 'IT/Software Development']": 2,
#          "['Engineering - Telecom/Technology', 'Sales/Retail', 'Engineering - Other']": 1,
#          "['Engineering - Telecom/Technology', 'Sales/Retail', 'IT/Software Development']": 4,
#          "['Engineering - Telecom/Technology', 'Sales/Retail', 'Installation/Maintenance/Repair']": 1,
#          "['Engineering - Telecom/Technology', 'Sales/Retail']": 12,
#          "['Engineering - Telecom/Technology', 'Training/Instructor', 'IT/Software Development']": 2,
#          "['Engineering - Telecom/Technology']": 32,
#          "['Fashion', 'Creative/Design/Art', 'Sales/Retail']": 1,
#          "['Fashion', 'Logistics/Supply Chain', 'Purchasing/Procurement']": 1,
#          "['Fashion', 'Sales/Retail']": 1,
#          "['Hospitality/Hotels/Food Services', 'Operations/Management']": 1,
#          "['Hospitality/Hotels/Food Services', 'Sales/Retail', 'Customer Service/Support']": 1,
#          "['Hospitality/Hotels/Food Services']": 5,
#          "['Human Resources', 'Accounting/Finance', 'Administration']": 1,
#          "['Human Resources', 'Accounting/Finance']": 3,
#          "['Human Resources', 'Administration']": 6,
#          "['Human Resources', 'C-Level Executive/GM/Director']": 1,
#          "['Human Resources', 'IT/Software Development']": 8,
#          "['Human Resources', 'Manufacturing/Production']": 1,
#          "['Human Resources', 'Operations/Management']": 1,
#          "['Human Resources']": 211,
#          "['IT/Software Development', 'Accounting/Finance', 'Customer Service/Support']": 1,
#          "['IT/Software Development', 'Accounting/Finance']": 12,
#          "['IT/Software Development', 'Administration']": 3,
#          "['IT/Software Development', 'Analyst/Research', 'Accounting/Finance']": 1,
#          "['IT/Software Development', 'Analyst/Research', 'Business Development']": 5,
#          "['IT/Software Development', 'Analyst/Research', 'Creative/Design/Art']": 1,
#          "['IT/Software Development', 'Analyst/Research', 'Engineering - Telecom/Technology']": 48,
#          "['IT/Software Development', 'Analyst/Research', 'Project/Program Management']": 2,
#          "['IT/Software Development', 'Analyst/Research', 'Sales/Retail']": 1,
#          "['IT/Software Development', 'Analyst/Research']": 14,
#          "['IT/Software Development', 'Banking', 'Analyst/Research']": 1,
#          "['IT/Software Development', 'Business Development', 'Customer Service/Support']": 1,
#          "['IT/Software Development', 'Business Development', 'Engineering - Telecom/Technology']": 1,
#          "['IT/Software Development', 'Business Development', 'Sales/Retail']": 2,
#          "['IT/Software Development', 'Creative/Design/Art', 'Engineering - Telecom/Technology']": 7,
#          "['IT/Software Development', 'Creative/Design/Art']": 38,
#          "['IT/Software Development', 'Customer Service/Support', 'Business Development']": 2,
#          "['IT/Software Development', 'Customer Service/Support', 'Engineering - Telecom/Technology']": 10,
#          "['IT/Software Development', 'Customer Service/Support', 'Project/Program Management']": 1,
#          "['IT/Software Development', 'Customer Service/Support', 'Sales/Retail']": 1,
#          "['IT/Software Development', 'Customer Service/Support']": 8,
#          "['IT/Software Development', 'Education/Teaching']": 1,
#          "['IT/Software Development', 'Engineering - Construction/Civil/Architecture', 'Engineering - Telecom/Technology']": 1,
#          "['IT/Software Development', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']": 3,
#          "['IT/Software Development', 'Engineering - Mechanical/Electrical']": 2,
#          "['IT/Software Development', 'Engineering - Other']": 2,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Accounting/Finance']": 1,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Administration']": 1,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Creative/Design/Art']": 27,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Customer Service/Support']": 17,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Education/Teaching']": 5,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical']": 8,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Engineering - Other']": 4,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Installation/Maintenance/Repair']": 18,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Manufacturing/Production']": 2,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Marketing/PR/Advertising']": 3,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Operations/Management']": 3,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Project/Program Management']": 26,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Quality']": 91,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'R&D/Science']": 1,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Sales/Retail']": 24,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Strategy/Consulting']": 2,
#          "['IT/Software Development', 'Engineering - Telecom/Technology', 'Writing/Editorial']": 2,
#          "['IT/Software Development', 'Engineering - Telecom/Technology']": 1489,
#          "['IT/Software Development', 'Installation/Maintenance/Repair', 'Business Development']": 2,
#          "['IT/Software Development', 'Installation/Maintenance/Repair', 'Customer Service/Support']": 2,
#          "['IT/Software Development', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']": 50,
#          "['IT/Software Development', 'Installation/Maintenance/Repair']": 10,
#          "['IT/Software Development', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 1,
#          "['IT/Software Development', 'Marketing/PR/Advertising']": 4,
#          "['IT/Software Development', 'Operations/Management', 'Engineering - Telecom/Technology']": 4,
#          "['IT/Software Development', 'Operations/Management']": 2,
#          "['IT/Software Development', 'Project/Program Management', 'Analyst/Research']": 2,
#          "['IT/Software Development', 'Project/Program Management', 'Business Development']": 2,
#          "['IT/Software Development', 'Project/Program Management', 'Engineering - Telecom/Technology']": 12,
#          "['IT/Software Development', 'Project/Program Management', 'Installation/Maintenance/Repair']": 1,
#          "['IT/Software Development', 'Project/Program Management']": 16,
#          "['IT/Software Development', 'Quality', 'Engineering - Telecom/Technology']": 19,
#          "['IT/Software Development', 'Quality']": 8,
#          "['IT/Software Development', 'Sales/Retail', 'Business Development']": 7,
#          "['IT/Software Development', 'Sales/Retail', 'Customer Service/Support']": 2,
#          "['IT/Software Development', 'Sales/Retail', 'Engineering - Telecom/Technology']": 5,
#          "['IT/Software Development', 'Sales/Retail']": 40,
#          "['IT/Software Development', 'Strategy/Consulting', 'Engineering - Telecom/Technology']": 2,
#          "['IT/Software Development', 'Strategy/Consulting']": 1,
#          "['IT/Software Development', 'Training/Instructor']": 4,
#          "['IT/Software Development', 'Writing/Editorial', 'Project/Program Management']": 2,
#          "['IT/Software Development', 'Writing/Editorial']": 1,
#          "['IT/Software Development']": 98,
#          "['Installation/Maintenance/Repair', 'Administration', 'Purchasing/Procurement']": 1,
#          "['Installation/Maintenance/Repair', 'Administration']": 3,
#          "['Installation/Maintenance/Repair', 'Business Development', 'IT/Software Development']": 2,
#          "['Installation/Maintenance/Repair', 'Customer Service/Support', 'Engineering - Mechanical/Electrical']": 3,
#          "['Installation/Maintenance/Repair', 'Customer Service/Support', 'IT/Software Development']": 3,
#          "['Installation/Maintenance/Repair', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']": 1,
#          "['Installation/Maintenance/Repair', 'Engineering - Construction/Civil/Architecture', 'Project/Program Management']": 1,
#          "['Installation/Maintenance/Repair', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']": 2,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'IT/Software Development']": 1,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']": 4,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Project/Program Management']": 3,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Sales/Retail']": 3,
#          "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']": 58,
#          "['Installation/Maintenance/Repair', 'Engineering - Oil & Gas/Energy', 'Engineering - Mechanical/Electrical']": 2,
#          "['Installation/Maintenance/Repair', 'Engineering - Other']": 8,
#          "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical']": 4,
#          "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'IT/Software Development']": 129,
#          "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'Project/Program Management']": 1,
#          "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'Sales/Retail']": 2,
#          "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']": 12,
#          "['Installation/Maintenance/Repair', 'IT/Software Development', 'Customer Service/Support']": 5,
#          "['Installation/Maintenance/Repair', 'IT/Software Development', 'Engineering - Mechanical/Electrical']": 1,
#          "['Installation/Maintenance/Repair', 'IT/Software Development', 'Engineering - Telecom/Technology']": 42,
#          "['Installation/Maintenance/Repair', 'IT/Software Development', 'Operations/Management']": 1,
#          "['Installation/Maintenance/Repair', 'IT/Software Development', 'Project/Program Management']": 1,
#          "['Installation/Maintenance/Repair', 'IT/Software Development']": 49,
#          "['Installation/Maintenance/Repair', 'Manufacturing/Production', 'Engineering - Mechanical/Electrical']": 2,
#          "['Installation/Maintenance/Repair', 'Manufacturing/Production']": 1,
#          "['Installation/Maintenance/Repair', 'Medical/Healthcare', 'R&D/Science']": 3,
#          "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Mechanical/Electrical']": 3,
#          "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Other']": 3,
#          "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Telecom/Technology']": 1,
#          "['Installation/Maintenance/Repair', 'Project/Program Management', 'Engineering - Mechanical/Electrical']": 1,
#          "['Installation/Maintenance/Repair']": 10,
#          "['Legal', 'Administration']": 2,
#          "['Legal']": 17,
#          "['Logistics/Supply Chain', 'Accounting/Finance']": 2,
#          "['Logistics/Supply Chain', 'Administration', 'Customer Service/Support']": 1,
#          "['Logistics/Supply Chain', 'Administration']": 4,
#          "['Logistics/Supply Chain', 'Analyst/Research']": 1,
#          "['Logistics/Supply Chain', 'Customer Service/Support', 'Sales/Retail']": 1,
#          "['Logistics/Supply Chain', 'Customer Service/Support']": 4,
#          "['Logistics/Supply Chain', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']": 1,
#          "['Logistics/Supply Chain', 'Engineering - Other', 'Manufacturing/Production']": 1,
#          "['Logistics/Supply Chain', 'Engineering - Other']": 1,
#          "['Logistics/Supply Chain', 'Manufacturing/Production']": 4,
#          "['Logistics/Supply Chain', 'Operations/Management', 'Administration']": 1,
#          "['Logistics/Supply Chain', 'Operations/Management', 'Engineering - Other']": 1,
#          "['Logistics/Supply Chain', 'Operations/Management']": 6,
#          "['Logistics/Supply Chain', 'Purchasing/Procurement', 'Engineering - Mechanical/Electrical']": 1,
#          "['Logistics/Supply Chain', 'Purchasing/Procurement', 'Human Resources']": 1,
#          "['Logistics/Supply Chain', 'Purchasing/Procurement']": 26,
#          "['Logistics/Supply Chain', 'Sales/Retail']": 5,
#          "['Logistics/Supply Chain']": 60,
#          "['Manufacturing/Production', 'Creative/Design/Art', 'Engineering - Mechanical/Electrical']": 1,
#          "['Manufacturing/Production', 'Engineering - Construction/Civil/Architecture', 'Creative/Design/Art']": 1,
#          "['Manufacturing/Production', 'Engineering - Mechanical/Electrical', 'Creative/Design/Art']": 1,
#          "['Manufacturing/Production', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']": 1,
#          "['Manufacturing/Production', 'Engineering - Mechanical/Electrical', 'Sales/Retail']": 1,
#          "['Manufacturing/Production', 'Engineering - Mechanical/Electrical']": 6,
#          "['Manufacturing/Production', 'Engineering - Other', 'Quality']": 2,
#          "['Manufacturing/Production', 'Engineering - Other', 'Sales/Retail']": 2,
#          "['Manufacturing/Production', 'Engineering - Other']": 8,
#          "['Manufacturing/Production', 'Engineering - Telecom/Technology', 'IT/Software Development']": 1,
#          "['Manufacturing/Production', 'Human Resources']": 1,
#          "['Manufacturing/Production', 'IT/Software Development', 'Engineering - Telecom/Technology']": 2,
#          "['Manufacturing/Production', 'Logistics/Supply Chain', 'Engineering - Other']": 1,
#          "['Manufacturing/Production', 'Logistics/Supply Chain']": 1,
#          "['Manufacturing/Production', 'Marketing/PR/Advertising']": 1,
#          "['Manufacturing/Production', 'Operations/Management', 'Engineering - Mechanical/Electrical']": 2,
#          "['Manufacturing/Production', 'Operations/Management', 'Logistics/Supply Chain']": 2,
#          "['Manufacturing/Production', 'Pharmaceutical', 'Project/Program Management']": 1,
#          "['Manufacturing/Production', 'Project/Program Management', 'Engineering - Mechanical/Electrical']": 1,
#          "['Manufacturing/Production', 'Project/Program Management', 'Pharmaceutical']": 1,
#          "['Manufacturing/Production', 'Quality', 'Operations/Management']": 1,
#          "['Manufacturing/Production', 'Quality']": 2,
#          "['Manufacturing/Production', 'R&D/Science', 'Engineering - Other']": 2,
#          "['Manufacturing/Production']": 2,
#          "['Marketing/PR/Advertising', 'Administration', 'Customer Service/Support']": 1,
#          "['Marketing/PR/Advertising', 'Administration', 'Operations/Management']": 1,
#          "['Marketing/PR/Advertising', 'Administration']": 1,
#          "['Marketing/PR/Advertising', 'Analyst/Research', 'Media/Journalism/Publishing']": 7,
#          "['Marketing/PR/Advertising', 'Analyst/Research', 'Sales/Retail']": 1,
#          "['Marketing/PR/Advertising', 'Analyst/Research']": 7,
#          "['Marketing/PR/Advertising', 'Business Development', 'Customer Service/Support']": 1,
#          "['Marketing/PR/Advertising', 'Business Development', 'Engineering - Other']": 1,
#          "['Marketing/PR/Advertising', 'Business Development', 'Media/Journalism/Publishing']": 2,
#          "['Marketing/PR/Advertising', 'Business Development', 'Sales/Retail']": 12,
#          "['Marketing/PR/Advertising', 'Business Development']": 24,
#          "['Marketing/PR/Advertising', 'Creative/Design/Art', 'Media/Journalism/Publishing']": 2,
#          "['Marketing/PR/Advertising', 'Creative/Design/Art', 'Sales/Retail']": 1,
#          "['Marketing/PR/Advertising', 'Creative/Design/Art', 'Writing/Editorial']": 3,
#          "['Marketing/PR/Advertising', 'Creative/Design/Art']": 52,
#          "['Marketing/PR/Advertising', 'Customer Service/Support', 'Business Development']": 2,
#          "['Marketing/PR/Advertising', 'Customer Service/Support', 'Media/Journalism/Publishing']": 2,
#          "['Marketing/PR/Advertising', 'Customer Service/Support', 'Sales/Retail']": 13,
#          "['Marketing/PR/Advertising', 'Customer Service/Support']": 13,
#          "['Marketing/PR/Advertising', 'Engineering - Mechanical/Electrical', 'Sales/Retail']": 2,
#          "['Marketing/PR/Advertising', 'Engineering - Other', 'Sales/Retail']": 1,
#          "['Marketing/PR/Advertising', 'Engineering - Telecom/Technology', 'IT/Software Development']": 4,
#          "['Marketing/PR/Advertising', 'IT/Software Development']": 4,
#          "['Marketing/PR/Advertising', 'Manufacturing/Production']": 2,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Analyst/Research']": 7,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Business Development']": 1,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Creative/Design/Art']": 14,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Operations/Management']": 7,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Sales/Retail']": 5,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Writing/Editorial']": 8,
#          "['Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 277,
#          "['Marketing/PR/Advertising', 'Medical/Healthcare', 'Sales/Retail']": 1,
#          "['Marketing/PR/Advertising', 'Medical/Healthcare']": 1,
#          "['Marketing/PR/Advertising', 'Operations/Management', 'IT/Software Development']": 1,
#          "['Marketing/PR/Advertising', 'Operations/Management', 'Sales/Retail']": 3,
#          "['Marketing/PR/Advertising', 'Operations/Management']": 5,
#          "['Marketing/PR/Advertising', 'Pharmaceutical', 'Sales/Retail']": 1,
#          "['Marketing/PR/Advertising', 'Project/Program Management']": 1,
#          "['Marketing/PR/Advertising', 'Sales/Retail', 'Business Development']": 6,
#          "['Marketing/PR/Advertising', 'Sales/Retail', 'Customer Service/Support']": 14,
#          "['Marketing/PR/Advertising', 'Sales/Retail', 'Media/Journalism/Publishing']": 1,
#          "['Marketing/PR/Advertising', 'Sales/Retail', 'Medical/Healthcare']": 2,
#          "['Marketing/PR/Advertising', 'Sales/Retail', 'Operations/Management']": 2,
#          "['Marketing/PR/Advertising', 'Sales/Retail']": 61,
#          "['Marketing/PR/Advertising', 'Training/Instructor']": 1,
#          "['Marketing/PR/Advertising', 'Writing/Editorial', 'Media/Journalism/Publishing']": 12,
#          "['Marketing/PR/Advertising', 'Writing/Editorial']": 5,
#          "['Marketing/PR/Advertising']": 85,
#          "['Media/Journalism/Publishing', 'Administration', 'Marketing/PR/Advertising']": 1,
#          "['Media/Journalism/Publishing', 'Administration']": 1,
#          "['Media/Journalism/Publishing', 'Analyst/Research', 'Marketing/PR/Advertising']": 4,
#          "['Media/Journalism/Publishing', 'Business Development', 'Marketing/PR/Advertising']": 4,
#          "['Media/Journalism/Publishing', 'Business Development', 'Sales/Retail']": 1,
#          "['Media/Journalism/Publishing', 'Creative/Design/Art']": 23,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Analyst/Research']": 4,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Business Development']": 4,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Creative/Design/Art']": 16,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Customer Service/Support']": 15,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'IT/Software Development']": 3,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Medical/Healthcare']": 3,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Operations/Management']": 1,
#          "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Project/Program Management']": 1,
# ...
#          "['Operations/Management', 'Logistics/Supply Chain']": 2,
#          "['Operations/Management', 'Manufacturing/Production', 'Engineering - Mechanical/Electrical']": 1,
#          "['Operations/Management', 'Manufacturing/Production']": 1,
#          "['Operations/Management', 'Marketing/PR/Advertising', 'Business Development']": 1,
#          "['Operations/Management', 'Marketing/PR/Advertising', 'IT/Software Development']": 2,
#          "['Operations/Management', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 4,
#          "['Operations/Management', 'Marketing/PR/Advertising', 'Medical/Healthcare']": 3,
#          "['Operations/Management', 'Marketing/PR/Advertising', 'Sales/Retail']": 4,
#          "['Operations/Management', 'Marketing/PR/Advertising']": 2,
#          "['Operations/Management', 'Medical/Healthcare', 'Project/Program Management']": 2,
#          "['Operations/Management', 'Medical/Healthcare']": 12,
#          "['Operations/Management', 'Pharmaceutical', 'Administration']": 1,
#          "['Operations/Management', 'Pharmaceutical']": 4,
#          "['Operations/Management', 'Project/Program Management', 'Customer Service/Support']": 1,
#          "['Operations/Management', 'Project/Program Management', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Operations/Management', 'Project/Program Management', 'Engineering - Telecom/Technology']": 1,
#          "['Operations/Management', 'Project/Program Management']": 1,
#          "['Operations/Management', 'Purchasing/Procurement']": 2,
#          "['Operations/Management', 'Sales/Retail', 'Business Development']": 3,
#          "['Operations/Management', 'Sales/Retail', 'Customer Service/Support']": 1,
#          "['Operations/Management', 'Sales/Retail']": 16,
#          "['Operations/Management', 'Strategy/Consulting']": 1,
#          "['Operations/Management', 'Training/Instructor']": 1,
#          "['Operations/Management', 'Writing/Editorial']": 1,
#          "['Operations/Management']": 7,
#          "['Pharmaceutical', 'Analyst/Research', 'Quality']": 1,
#          "['Pharmaceutical', 'Analyst/Research', 'R&D/Science']": 1,
#          "['Pharmaceutical', 'Customer Service/Support', 'Medical/Healthcare']": 1,
#          "['Pharmaceutical', 'Customer Service/Support']": 1,
#          "['Pharmaceutical', 'IT/Software Development']": 1,
#          "['Pharmaceutical', 'Manufacturing/Production']": 1,
#          "['Pharmaceutical', 'Operations/Management']": 2,
#          "['Pharmaceutical', 'Project/Program Management', 'R&D/Science']": 1,
#          "['Pharmaceutical', 'Project/Program Management']": 2,
#          "['Pharmaceutical', 'Quality', 'Medical/Healthcare']": 5,
#          "['Pharmaceutical', 'R&D/Science', 'Analyst/Research']": 1,
#          "['Pharmaceutical', 'R&D/Science', 'Medical/Healthcare']": 8,
#          "['Pharmaceutical', 'R&D/Science', 'Project/Program Management']": 2,
#          "['Pharmaceutical', 'Sales/Retail', 'Marketing/PR/Advertising']": 1,
#          "['Pharmaceutical', 'Sales/Retail', 'Medical/Healthcare']": 2,
#          "['Pharmaceutical', 'Sales/Retail']": 20,
#          "['Pharmaceutical']": 5,
#          "['Project/Program Management', 'Accounting/Finance']": 1,
#          "['Project/Program Management', 'Administration', 'Engineering - Other']": 1,
#          "['Project/Program Management', 'Analyst/Research', 'IT/Software Development']": 3,
#          "['Project/Program Management', 'Analyst/Research']": 1,
#          "['Project/Program Management', 'Business Development', 'IT/Software Development']": 2,
#          "['Project/Program Management', 'Creative/Design/Art', 'Engineering - Construction/Civil/Architecture']": 2,
#          "['Project/Program Management', 'Customer Service/Support']": 1,
#          "['Project/Program Management', 'Engineering - Construction/Civil/Architecture', 'Administration']": 2,
#          "['Project/Program Management', 'Engineering - Construction/Civil/Architecture', 'Analyst/Research']": 4,
#          "['Project/Program Management', 'Engineering - Construction/Civil/Architecture']": 19,
#          "['Project/Program Management', 'Engineering - Mechanical/Electrical', 'Engineering - Other']": 2,
#          "['Project/Program Management', 'Engineering - Mechanical/Electrical']": 3,
#          "['Project/Program Management', 'Engineering - Other', 'Engineering - Mechanical/Electrical']": 1,
#          "['Project/Program Management', 'Engineering - Other']": 1,
#          "['Project/Program Management', 'Engineering - Telecom/Technology', 'IT/Software Development']": 23,
#          "['Project/Program Management', 'Hospitality/Hotels/Food Services', 'Operations/Management']": 1,
#          "['Project/Program Management', 'IT/Software Development', 'Customer Service/Support']": 1,
#          "['Project/Program Management', 'IT/Software Development', 'Engineering - Telecom/Technology']": 19,
#          "['Project/Program Management', 'IT/Software Development', 'Installation/Maintenance/Repair']": 1,
#          "['Project/Program Management', 'IT/Software Development', 'Writing/Editorial']": 2,
#          "['Project/Program Management', 'IT/Software Development']": 22,
#          "['Project/Program Management', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']": 1,
#          "['Project/Program Management', 'Installation/Maintenance/Repair', 'IT/Software Development']": 1,
#          "['Project/Program Management', 'Marketing/PR/Advertising']": 1,
#          "['Project/Program Management', 'Operations/Management', 'Engineering - Telecom/Technology']": 1,
#          "['Project/Program Management', 'Operations/Management']": 1,
#          "['Project/Program Management', 'Pharmaceutical', 'R&D/Science']": 1,
#          "['Project/Program Management']": 31,
#          "['Purchasing/Procurement', 'Administration', 'Installation/Maintenance/Repair']": 1,
#          "['Purchasing/Procurement', 'Administration', 'Operations/Management']": 1,
#          "['Purchasing/Procurement', 'Administration']": 4,
#          "['Purchasing/Procurement', 'Engineering - Construction/Civil/Architecture']": 3,
#          "['Purchasing/Procurement', 'Engineering - Mechanical/Electrical']": 9,
#          "['Purchasing/Procurement', 'Engineering - Other', 'Logistics/Supply Chain']": 1,
#          "['Purchasing/Procurement', 'Engineering - Other']": 2,
#          "['Purchasing/Procurement', 'Installation/Maintenance/Repair', 'Administration']": 1,
#          "['Purchasing/Procurement', 'Logistics/Supply Chain', 'Engineering - Mechanical/Electrical']": 1,
#          "['Purchasing/Procurement', 'Logistics/Supply Chain', 'Medical/Healthcare']": 3,
#          "['Purchasing/Procurement', 'Logistics/Supply Chain', 'Operations/Management']": 2,
#          "['Purchasing/Procurement', 'Logistics/Supply Chain']": 11,
#          "['Purchasing/Procurement', 'Operations/Management']": 4,
#          "['Purchasing/Procurement']": 35,
#          "['Quality', 'Administration', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Quality', 'Analyst/Research', 'Pharmaceutical']": 2,
#          "['Quality', 'Banking']": 2,
#          "['Quality', 'Education/Teaching']": 1,
#          "['Quality', 'Engineering - Construction/Civil/Architecture', 'Manufacturing/Production']": 1,
#          "['Quality', 'Engineering - Construction/Civil/Architecture']": 8,
#          "['Quality', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']": 1,
#          "['Quality', 'Engineering - Mechanical/Electrical']": 6,
#          "['Quality', 'Engineering - Other', 'Engineering - Mechanical/Electrical']": 1,
#          "['Quality', 'Engineering - Other', 'Manufacturing/Production']": 2,
#          "['Quality', 'Engineering - Other', 'R&D/Science']": 4,
#          "['Quality', 'Engineering - Other']": 9,
#          "['Quality', 'Engineering - Telecom/Technology', 'IT/Software Development']": 80,
#          "['Quality', 'IT/Software Development', 'Engineering - Telecom/Technology']": 36,
#          "['Quality', 'IT/Software Development']": 12,
#          "['Quality', 'Manufacturing/Production', 'Engineering - Mechanical/Electrical']": 1,
#          "['Quality', 'Manufacturing/Production']": 3,
#          "['Quality', 'Medical/Healthcare', 'Pharmaceutical']": 8,
#          "['Quality', 'Medical/Healthcare']": 7,
#          "['Quality', 'Operations/Management', 'Engineering - Mechanical/Electrical']": 1,
#          "['Quality', 'Operations/Management', 'Manufacturing/Production']": 1,
#          "['Quality', 'Operations/Management']": 2,
#          "['Quality', 'Pharmaceutical', 'Manufacturing/Production']": 1,
#          "['Quality', 'Project/Program Management', 'IT/Software Development']": 1,
#          "['Quality', 'R&D/Science', 'Analyst/Research']": 1,
#          "['Quality', 'R&D/Science', 'Manufacturing/Production']": 2,
#          "['Quality', 'R&D/Science', 'Pharmaceutical']": 1,
#          "['Quality', 'R&D/Science']": 2,
#          "['Quality', 'Training/Instructor', 'Education/Teaching']": 1,
#          "['Quality']": 13,
#          "['R&D/Science', 'Education/Teaching', 'Writing/Editorial']": 1,
#          "['R&D/Science', 'Education/Teaching']": 4,
#          "['R&D/Science', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']": 3,
#          "['R&D/Science', 'Engineering - Other', 'Quality']": 2,
#          "['R&D/Science', 'Engineering - Other']": 2,
#          "['R&D/Science', 'Engineering - Telecom/Technology', 'IT/Software Development']": 4,
#          "['R&D/Science', 'Installation/Maintenance/Repair', 'Medical/Healthcare']": 2,
#          "['R&D/Science', 'Medical/Healthcare', 'Pharmaceutical']": 11,
#          "['R&D/Science', 'Pharmaceutical', 'Sales/Retail']": 5,
#          "['R&D/Science', 'Project/Program Management', 'Pharmaceutical']": 2,
#          "['R&D/Science', 'Quality', 'Engineering - Other']": 2,
#          "['R&D/Science', 'Quality']": 4,
#          "['R&D/Science', 'Sales/Retail', 'Engineering - Other']": 1,
#          "['R&D/Science']": 8,
#          "['Sales/Retail', 'Administration']": 1,
#          "['Sales/Retail', 'Business Development', 'Customer Service/Support']": 5,
#          "['Sales/Retail', 'Business Development', 'IT/Software Development']": 1,
#          "['Sales/Retail', 'Business Development', 'Marketing/PR/Advertising']": 1,
#          "['Sales/Retail', 'Business Development']": 45,
#          "['Sales/Retail', 'Creative/Design/Art']": 1,
#          "['Sales/Retail', 'Customer Service/Support', 'Business Development']": 4,
#          "['Sales/Retail', 'Customer Service/Support', 'Hospitality/Hotels/Food Services']": 1,
#          "['Sales/Retail', 'Customer Service/Support', 'IT/Software Development']": 12,
#          "['Sales/Retail', 'Customer Service/Support', 'Medical/Healthcare']": 3,
#          "['Sales/Retail', 'Customer Service/Support']": 137,
#          "['Sales/Retail', 'Engineering - Construction/Civil/Architecture']": 4,
#          "['Sales/Retail', 'Engineering - Mechanical/Electrical', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Sales/Retail', 'Engineering - Mechanical/Electrical', 'Engineering - Other']": 1,
#          "['Sales/Retail', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']": 2,
#          "['Sales/Retail', 'Engineering - Mechanical/Electrical']": 36,
#          "['Sales/Retail', 'Engineering - Other']": 9,
#          "['Sales/Retail', 'Engineering - Telecom/Technology', 'IT/Software Development']": 31,
#          "['Sales/Retail', 'Engineering - Telecom/Technology', 'Operations/Management']": 1,
#          "['Sales/Retail', 'Engineering - Telecom/Technology']": 5,
#          "['Sales/Retail', 'IT/Software Development', 'Business Development']": 4,
#          "['Sales/Retail', 'IT/Software Development', 'Customer Service/Support']": 1,
#          "['Sales/Retail', 'IT/Software Development', 'Engineering - Mechanical/Electrical']": 1,
#          "['Sales/Retail', 'IT/Software Development', 'Engineering - Telecom/Technology']": 14,
#          "['Sales/Retail', 'IT/Software Development']": 35,
#          "['Sales/Retail', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']": 1,
#          "['Sales/Retail', 'Logistics/Supply Chain', 'Engineering - Construction/Civil/Architecture']": 1,
#          "['Sales/Retail', 'Logistics/Supply Chain']": 6,
#          "['Sales/Retail', 'Manufacturing/Production']": 1,
#          "['Sales/Retail', 'Marketing/PR/Advertising', 'Administration']": 1,
#          "['Sales/Retail', 'Marketing/PR/Advertising', 'Business Development']": 30,
#          "['Sales/Retail', 'Marketing/PR/Advertising', 'Customer Service/Support']": 3,
#          "['Sales/Retail', 'Marketing/PR/Advertising', 'Engineering - Mechanical/Electrical']": 1,
#          "['Sales/Retail', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 3,
#          "['Sales/Retail', 'Marketing/PR/Advertising']": 18,
#          "['Sales/Retail', 'Media/Journalism/Publishing', 'Business Development']": 1,
#          "['Sales/Retail', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 7,
#          "['Sales/Retail', 'Medical/Healthcare', 'Customer Service/Support']": 1,
#          "['Sales/Retail', 'Medical/Healthcare', 'Pharmaceutical']": 5,
#          "['Sales/Retail', 'Medical/Healthcare', 'R&D/Science']": 1,
#          "['Sales/Retail', 'Medical/Healthcare']": 7,
#          "['Sales/Retail', 'Operations/Management', 'Business Development']": 4,
#          "['Sales/Retail', 'Operations/Management']": 10,
#          "['Sales/Retail', 'Pharmaceutical', 'Engineering - Other']": 1,
#          "['Sales/Retail', 'Pharmaceutical']": 4,
#          "['Sales/Retail', 'Project/Program Management', 'Medical/Healthcare']": 1,
#          "['Sales/Retail', 'R&D/Science', 'Medical/Healthcare']": 1,
#          "['Sales/Retail', 'Tourism/Travel']": 1,
#          "['Sales/Retail', 'Training/Instructor']": 1,
#          "['Sales/Retail']": 583,
#          "['Sports and Leisure', 'Education/Teaching']": 2,
#          "['Strategy/Consulting', 'Accounting/Finance']": 1,
#          "['Strategy/Consulting', 'IT/Software Development', 'Engineering - Telecom/Technology']": 4,
#          "['Tourism/Travel', 'Customer Service/Support', 'Sales/Retail']": 1,
#          "['Tourism/Travel', 'Customer Service/Support']": 1,
#          "['Tourism/Travel', 'Operations/Management']": 1,
#          "['Tourism/Travel', 'Sales/Retail', 'Customer Service/Support']": 1,
#          "['Tourism/Travel']": 1,
#          "['Training/Instructor', 'Creative/Design/Art']": 1,
#          "['Training/Instructor', 'Education/Teaching', 'IT/Software Development']": 1,
#          "['Training/Instructor', 'Education/Teaching']": 18,
#          "['Training/Instructor', 'Engineering - Telecom/Technology', 'IT/Software Development']": 1,
#          "['Training/Instructor', 'IT/Software Development']": 2,
#          "['Training/Instructor', 'Marketing/PR/Advertising']": 3,
#          "['Training/Instructor', 'Medical/Healthcare', 'Education/Teaching']": 5,
#          "['Training/Instructor', 'Operations/Management', 'Education/Teaching']": 2,
#          "['Training/Instructor', 'Sales/Retail']": 1,
#          "['Training/Instructor']": 15,
#          "['Writing/Editorial', 'Education/Teaching', 'Medical/Healthcare']": 2,
#          "['Writing/Editorial', 'Education/Teaching']": 2,
#          "['Writing/Editorial', 'IT/Software Development', 'Engineering - Telecom/Technology']": 1,
#          "['Writing/Editorial', 'Marketing/PR/Advertising', 'Creative/Design/Art']": 2,
#          "['Writing/Editorial', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']": 28,
#          "['Writing/Editorial', 'Marketing/PR/Advertising']": 3,
#          "['Writing/Editorial', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']": 17,
#          "['Writing/Editorial', 'Media/Journalism/Publishing']": 7,
#          "['Writing/Editorial', 'Medical/Healthcare', 'Media/Journalism/Publishing']": 1,
#          "['Writing/Editorial', 'Quality', 'Customer Service/Support']": 1,
#          "['Writing/Editorial', 'R&D/Science']": 1,
#          "['Writing/Editorial']": 24,
#          nan: 117})

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data cleaning is the process of preparing data for analysis by removing or modifying data that is incorrect, incomplete, irrelevant, duplicated, or improperly formatted. This data is usually not necessary or helpful when it comes to analyzing data because it may provide inaccurate results. <br>
#  **garbage in .. garbage out!!**

# %% [markdown]
# Since our model expects the user to input the `Title` then it recommends `jobFunction/s` to it. we see that we have *117* cells in `jobFunction` that is not annotated (with `nan` value). we may replace `nan` with some value but in our situation I think the simplest and best way is to remove `nans`

# %% [markdown]
# you can do it easily with [DataFrame.dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) in pandas.

# %%
dataset.dropna(subset=['jobFunction'], inplace=True)

# %% [markdown]
# Now the next step after removing the `nans`, we want to get insights about the `jobFunction` column considering it our label that the model will predict.<br>
#
# Lets play with the dataset and get the unique job functions (*number of classes*) in the dataset

# %%
def from_str_to_list(text):
    '''
    This function takes a string object (with a list format) then parsing it 
    and converting it to list 
    '''
    str_cleaned = re.sub('[\'"\[\]]', '', text)
    return [token.strip() for token in str_cleaned.split(',')]

# %%
# Convert jobFunctions from list of strings to a list of lists 
job_functions = [from_str_to_list(function) for function in dataset['jobFunction']]

# flatten jobFunctions to deal with each function separately
job_functions_flattened = [item for sublist in job_functions for item in sublist]

# %%
job_functions_flattened
# Out:
# ['Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'Education/Teaching',
#  'Administration',
#  'Operations/Management',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Accounting/Finance',
#  'Sales/Retail',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Education/Teaching',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Accounting/Finance',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Creative/Design/Art',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Engineering - Mechanical/Electrical',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Education/Teaching',
#  'Administration',
#  'Sales/Retail',
#  'Administration',
#  'Operations/Management',
#  'Sales/Retail',
#  'Training/Instructor',
#  'Education/Teaching',
#  'R&D/Science',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Logistics/Supply Chain',
#  'Purchasing/Procurement',
#  'Accounting/Finance',
#  'Project/Program Management',
#  'IT/Software Development',
#  'Project/Program Management',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Project/Program Management',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Creative/Design/Art',
#  'Engineering - Construction/Civil/Architecture',
#  'Human Resources',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Quality',
#  'Human Resources',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'Project/Program Management',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Quality',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Writing/Editorial',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Customer Service/Support',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Media/Journalism/Publishing',
#  'Creative/Design/Art',
#  'Engineering - Mechanical/Electrical',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Writing/Editorial',
#  'Accounting/Finance',
#  'Administration',
#  'Sales/Retail',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Business Development',
#  'IT/Software Development',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Mechanical/Electrical',
#  'Creative/Design/Art',
#  'Project/Program Management',
#  'Analyst/Research',
#  'IT/Software Development',
#  'Administration',
#  'Analyst/Research',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Administration',
#  'Training/Instructor',
#  'Education/Teaching',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Business Development',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'Engineering - Construction/Civil/Architecture',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Project/Program Management',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Education/Teaching',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Media/Journalism/Publishing',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Construction/Civil/Architecture',
#  'Legal',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Administration',
#  'Education/Teaching',
#  'Sports and Leisure',
#  'Analyst/Research',
#  'Operations/Management',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Education/Teaching',
#  'Analyst/Research',
#  'Installation/Maintenance/Repair',
#  'Administration',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Administration',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Business Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Accounting/Finance',
#  'Administration',
#  'Engineering - Telecom/Technology',
#  'Engineering - Mechanical/Electrical',
#  'Installation/Maintenance/Repair',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Quality',
#  'Medical/Healthcare',
#  'Marketing/PR/Advertising',
#  'Business Development',
#  'Engineering - Other',
#  'Creative/Design/Art',
#  'Creative/Design/Art',
#  'Logistics/Supply Chain',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Engineering - Construction/Civil/Architecture',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'Operations/Management',
#  'Logistics/Supply Chain',
#  'Engineering - Other',
#  'Engineering - Construction/Civil/Architecture',
#  'Business Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Administration',
#  'Project/Program Management',
#  'Engineering - Construction/Civil/Architecture',
#  'Accounting/Finance',
#  'Logistics/Supply Chain',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'Education/Teaching',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Quality',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'Accounting/Finance',
#  'Sales/Retail',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Creative/Design/Art',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Marketing/PR/Advertising',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Writing/Editorial',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Creative/Design/Art',
#  'Sales/Retail',
#  'Business Development',
#  'Education/Teaching',
#  'Customer Service/Support',
#  'Administration',
#  'Education/Teaching',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Medical/Healthcare',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Business Development',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Accounting/Finance',
#  'Administration',
#  'Operations/Management',
#  'Logistics/Supply Chain',
#  'Administration',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Business Development',
#  'Accounting/Finance',
#  'Operations/Management',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Media/Journalism/Publishing',
#  'Administration',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Logistics/Supply Chain',
#  'Accounting/Finance',
#  'Sales/Retail',
#  'Operations/Management',
#  'IT/Software Development',
#  'Engineering - Mechanical/Electrical',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Logistics/Supply Chain',
#  'Administration',
#  'Customer Service/Support',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Quality',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Customer Service/Support',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Media/Journalism/Publishing',
#  'Writing/Editorial',
#  'Marketing/PR/Advertising',
#  'Marketing/PR/Advertising',
#  'Writing/Editorial',
#  'Media/Journalism/Publishing',
#  'Education/Teaching',
#  'Administration',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Engineering - Mechanical/Electrical',
#  'Operations/Management',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Construction/Civil/Architecture',
#  'Engineering - Other',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Quality',
#  'R&D/Science',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'Creative/Design/Art',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Pharmaceutical',
#  'Sales/Retail',
#  'Education/Teaching',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Mechanical/Electrical',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Quality',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Administration',
#  'Accounting/Finance',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Administration',
#  'Operations/Management',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Business Development',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Marketing/PR/Advertising',
#  'Writing/Editorial',
#  'Media/Journalism/Publishing',
#  'Education/Teaching',
#  'Quality',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Education/Teaching',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Medical/Healthcare',
#  'Human Resources',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Education/Teaching',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Administration',
#  'Project/Program Management',
#  'Engineering - Construction/Civil/Architecture',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Purchasing/Procurement',
#  'Engineering - Mechanical/Electrical',
#  'Project/Program Management',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Quality',
#  'Media/Journalism/Publishing',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Administration',
#  'Human Resources',
#  'Business Development',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Project/Program Management',
#  'Education/Teaching',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Operations/Management',
#  'Business Development',
#  'Accounting/Finance',
#  'Operations/Management',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Education/Teaching',
#  'Business Development',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Education/Teaching',
#  'Creative/Design/Art',
#  'Business Development',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'IT/Software Development',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'Administration',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Administration',
#  'Marketing/PR/Advertising',
#  'Administration',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'Purchasing/Procurement',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Business Development',
#  'Engineering - Construction/Civil/Architecture',
#  'Engineering - Mechanical/Electrical',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Legal',
#  'Quality',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Pharmaceutical',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Education/Teaching',
#  'Administration',
#  'Engineering - Construction/Civil/Architecture',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Quality',
#  'Customer Service/Support',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Installation/Maintenance/Repair',
#  'Engineering - Mechanical/Electrical',
#  'Creative/Design/Art',
#  'Manufacturing/Production',
#  'Engineering - Other',
#  'Engineering - Telecom/Technology',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Writing/Editorial',
#  'Marketing/PR/Advertising',
#  'Installation/Maintenance/Repair',
#  'Business Development',
#  'IT/Software Development',
#  'Education/Teaching',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Education/Teaching',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Creative/Design/Art',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Human Resources',
#  'Administration',
#  'Customer Service/Support',
#  'Administration',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Quality',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Creative/Design/Art',
#  'Education/Teaching',
#  'Sales/Retail',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'Engineering - Mechanical/Electrical',
#  'Customer Service/Support',
#  'Engineering - Mechanical/Electrical',
#  'Engineering - Mechanical/Electrical',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Other',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Media/Journalism/Publishing',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Administration',
#  'Administration',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Business Development',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Administration',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Engineering - Mechanical/Electrical',
#  'Media/Journalism/Publishing',
#  'Writing/Editorial',
#  'Marketing/PR/Advertising',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Business Development',
#  'Sales/Retail',
#  'Human Resources',
#  'Sales/Retail',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'Education/Teaching',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Marketing/PR/Advertising',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Human Resources',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Education/Teaching',
#  'Accounting/Finance',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Oil & Gas/Energy',
#  'Sales/Retail',
#  'Administration',
#  'Creative/Design/Art',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Purchasing/Procurement',
#  'Logistics/Supply Chain',
#  'Pharmaceutical',
#  'Sales/Retail',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Mechanical/Electrical',
#  'IT/Software Development',
#  'Strategy/Consulting',
#  'Administration',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Education/Teaching',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Business Development',
#  'Customer Service/Support',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'R&D/Science',
#  'Medical/Healthcare',
#  'Pharmaceutical',
#  'Writing/Editorial',
#  'Manufacturing/Production',
#  'Operations/Management',
#  'Logistics/Supply Chain',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Education/Teaching',
#  'Engineering - Telecom/Technology',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'Administration',
#  'Creative/Design/Art',
#  'Operations/Management',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Project/Program Management',
#  'IT/Software Development',
#  'Administration',
#  'Analyst/Research',
#  'Installation/Maintenance/Repair',
#  'Business Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Mechanical/Electrical',
#  'Sales/Retail',
#  'Operations/Management',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Customer Service/Support',
#  'Administration',
#  'Operations/Management',
#  'Business Development',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Project/Program Management',
#  'Engineering - Mechanical/Electrical',
#  'Engineering - Other',
#  'IT/Software Development',
#  'Project/Program Management',
#  'Customer Service/Support',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Accounting/Finance',
#  'Quality',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Education/Teaching',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'R&D/Science',
#  'Medical/Healthcare',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Purchasing/Procurement',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Quality',
#  'Engineering - Telecom/Technology',
#  'Quality',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Administration',
#  'Sales/Retail',
#  'Creative/Design/Art',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Purchasing/Procurement',
#  'Education/Teaching',
#  'Administration',
#  'Quality',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Accounting/Finance',
#  'Administration',
#  'Education/Teaching',
#  'Administration',
#  'Operations/Management',
#  'Operations/Management',
#  'Purchasing/Procurement',
#  'Sales/Retail',
#  'Engineering - Other',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Accounting/Finance',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Project/Program Management',
#  'Engineering - Mechanical/Electrical',
#  'Accounting/Finance',
#  'Quality',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Project/Program Management',
#  'IT/Software Development',
#  'Manufacturing/Production',
#  'Engineering - Other',
#  'Administration',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Customer Service/Support',
#  'Administration',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Marketing/PR/Advertising',
#  'Operations/Management',
#  'Administration',
#  'Customer Service/Support',
#  'Manufacturing/Production',
#  'Engineering - Other',
#  'Sales/Retail',
#  'Analyst/Research',
#  'Engineering - Construction/Civil/Architecture',
#  'Project/Program Management',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'Customer Service/Support',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Installation/Maintenance/Repair',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Creative/Design/Art',
#  'Engineering - Construction/Civil/Architecture',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Quality',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'Administration',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Business Development',
#  'IT/Software Development',
#  'Analyst/Research',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Installation/Maintenance/Repair',
#  'IT/Software Development',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Creative/Design/Art',
#  'Training/Instructor',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Creative/Design/Art',
#  'Media/Journalism/Publishing',
#  'Marketing/PR/Advertising',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Customer Service/Support',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Administration',
#  'Accounting/Finance',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Marketing/PR/Advertising',
#  'Business Development',
#  'Pharmaceutical',
#  'Operations/Management',
#  'Engineering - Telecom/Technology',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Analyst/Research',
#  'Sales/Retail',
#  'Creative/Design/Art',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Analyst/Research',
#  'Engineering - Telecom/Technology',
#  'Sales/Retail',
#  'IT/Software Development',
#  'Accounting/Finance',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'Engineering - Construction/Civil/Architecture',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  ...]

# %% [markdown]
# To get the unique job functions with a simple way, you can use a `set`

# %%
unique_job_functions_flattened = set(job_functions_flattened)

classes = list(unique_job_functions_flattened)
print('number of classes is {}' .format(len(classes)))
# Out:
# number of classes is 37

# %% [markdown]
# ##### so we have **37 classes** that our model should recommend from them based on the employee's `title`

# %% [markdown]
# According to the job title in our dataset we want to see the frequency of the words in each title to know the most important words our model should preserve

# %%
title_words = [word for title in dataset['title'] for word in title.split()]

# %%
Counter(title_words)
# Out:
# Counter({'Full': 246,
#          'Stack': 264,
#          'PHP': 169,
#          'Developer': 2064,
#          'CISCO': 2,
#          'Collaboration': 3,
#          'Specialist': 1109,
#          'Engineer': 1308,
#          'Senior': 1913,
#          'Back': 31,
#          'End-PHP': 1,
#          'UX': 27,
#          'Designer': 509,
#          'Java': 120,
#          'Technical': 345,
#          'Lead': 130,
#          'Support': 242,
#          'iOS': 129,
#          'Mechanical': 86,
#          'Real': 131,
#          'Estate': 126,
#          'Sales': 1220,
#          '-': 1983,
#          '10th': 10,
#          'of': 50,
#          'Ramadan': 13,
#          'School': 29,
#          'Principal': 11,
#          'Representative': 414,
#          'Accountant': 279,
#          'Indoor': 43,
#          'Executive': 501,
#          'Full-Stack': 29,
#          'Joomla': 6,
#          'Expert': 17,
#          'English': 228,
#          'Teacher': 322,
#          'Assistant': 209,
#          'Marketing': 463,
#          'Coordinator': 158,
#          'Business': 333,
#          'Website': 7,
#          'Chief': 22,
#          'Front-End': 156,
#          'Account': 315,
#          'Manager': 1179,
#          'Google': 21,
#          'Cloud': 36,
#          'Back-End': 94,
#          'Video': 21,
#          'Editor': 23,
#          'Digital': 282,
#          'Office': 143,
#          'German': 34,
#          'American': 4,
#          'Personal': 39,
#          'Coordinator/Telesales': 1,
#          'Computer': 25,
#          'Programming': 3,
#          'Instructor': 75,
#          'R&D': 11,
#          'Chemist': 13,
#          'Supervisor': 85,
#          'ODOO': 9,
#          'Purchasing': 51,
#          'and': 75,
#          'Logistics': 38,
#          'Accounts': 34,
#          'Receivable': 17,
#          'PMO': 5,
#          '(Project': 3,
#          'Management': 47,
#          'Office)': 3,
#          'Software': 684,
#          'Project': 228,
#          '/': 241,
#          'Analyst': 182,
#          'WordPress': 58,
#          'WooCommerce': 6,
#          'Qalubia': 16,
#          'Modifications': 1,
#          'HR': 109,
#          'Generalist': 28,
#          'ERP': 103,
#          'Implementer': 57,
#          'Broker': 4,
#          'Quality': 170,
#          'SEO': 60,
#          'Cairo': 64,
#          'Planning': 43,
#          'Sharqia': 24,
#          'Costing': 3,
#          '&': 462,
#          'Budgeting': 6,
#          'Officer': 81,
#          'Alexandria': 406,
#          'Financial': 68,
#          'Consultant': 312,
#          'Tester': 60,
#          '.Net': 177,
#          'Social': 223,
#          'Media': 272,
#          'Customer': 198,
#          'Service': 141,
#          'Agent': 168,
#          '(English)': 2,
#          'SEO/SEM': 9,
#          '2D': 7,
#          'Graphic': 284,
#          'Electrical': 71,
#          'Site': 67,
#          'Tech': 13,
#          'Arabic': 26,
#          'Translator': 10,
#          'AP': 6,
#          'Administrative': 55,
#          'Intern': 98,
#          'Property': 99,
#          'Virtual': 1,
#          'Partner': 12,
#          'Application': 119,
#          'Pre-Sales': 37,
#          'Riyadh': 18,
#          'UI/UX': 119,
#          'Help': 48,
#          'Desk': 72,
#          'Admin': 144,
#          '(Research/Wireframes/Prototypes)': 3,
#          'IT': 219,
#          'Pre': 10,
#          'French': 69,
#          'Implementer/Business': 5,
#          'Android': 125,
#          'Team': 211,
#          'Leader': 164,
#          '.NET': 116,
#          'Secretary': 79,
#          'Nasr': 22,
#          'City': 56,
#          '(': 63,
#          'Engineering': 24,
#          ')': 48,
#          'CRM': 28,
#          '(Salesforce)': 3,
#          'Course': 3,
#          'Telesales': 101,
#          'Mid': 10,
#          'Web': 280,
#          '3D': 38,
#          'Associate': 39,
#          'Civil': 34,
#          'Lawyer': 6,
#          'Receptionist': 85,
#          'Physical': 6,
#          'Education': 8,
#          'Female': 6,
#          'Product': 124,
#          'Owner': 43,
#          'Key': 17,
#          'Nursery': 20,
#          'Transportation': 2,
#          'Front': 121,
#          'Junior': 169,
#          '(Microsoft': 6,
#          'Products)': 5,
#          'Mohandessein': 1,
#          'Maintenance': 88,
#          'Telecom': 7,
#          'Linux': 22,
#          'Administrator': 131,
#          'QA': 12,
#          'Medical': 115,
#          'Conferences': 3,
#          'Development': 261,
#          'Sheraton': 5,
#          'CAD': 3,
#          'Interior': 13,
#          'Stock': 6,
#          'Keeper': 9,
#          'Angular': 57,
#          '4+': 5,
#          'Presales': 10,
#          'Operations': 60,
#          '(Engineer)': 4,
#          '(Construction)': 2,
#          'Treasury': 8,
#          'Fleet': 9,
#          'for': 5,
#          'Light': 10,
#          'Trucks': 4,
#          'AutoCAD': 3,
#          'Draft-man': 3,
#          'Outdoor': 111,
#          'معلم': 3,
#          'لغة': 5,
#          'عربية': 5,
#          'QC': 60,
#          'Spanish': 8,
#          'Equipment': 2,
#          'Finance': 25,
#          'Advertising': 21,
#          'Solutions': 17,
#          'Content': 149,
#          'Creator': 54,
#          'Indonesia': 21,
#          '#1': 6,
#          '|': 86,
#          'ScaleUP': 14,
#          '-GE': 9,
#          '-RS': 7,
#          'KG': 15,
#          'Maths': 8,
#          'Pediatrics': 4,
#          'Doctor': 8,
#          '(Code:': 1,
#          'PD101)': 1,
#          'Marketer': 6,
#          '"Laravel"': 1,
#          'Administration': 18,
#          'Heavy': 2,
#          'Security': 72,
#          'Festival': 15,
#          'Mall': 6,
#          'Manager-Offline/Printing': 4,
#          'Planning,': 1,
#          'Reporting': 8,
#          'Brand': 11,
#          'Moderator': 32,
#          'Mobile': 149,
#          'Android/iOS': 9,
#          'End': 115,
#          'Vue.JS': 3,
#          'In': 49,
#          'India': 68,
#          'GT': 23,
#          'Cost': 24,
#          'Store': 9,
#          'Control': 117,
#          'Director': 51,
#          'Email': 3,
#          'Campaign': 3,
#          'Tunisia': 25,
#          'GE': 72,
#          'Land': 2,
#          'Surveyor': 5,
#          'MVC': 22,
#          'Finalizer': 5,
#          'Doctors': 6,
#          'Testing': 62,
#          'Document': 10,
#          'Controller': 21,
#          'Oracle': 69,
#          'Database': 26,
#          'Flutter': 13,
#          'International': 17,
#          'Trade': 6,
#          'Fairs': 3,
#          'Exhibitions': 5,
#          'Professional': 12,
#          'Odoo': 53,
#          'Creative': 43,
#          'Online': 44,
#          'Science/Information': 7,
#          'Technology': 19,
#          'Tutor': 25,
#          'Dermatologist': 1,
#          'دكتور': 1,
#          'جلدية': 1,
#          'Recruitment': 48,
#          'Minya': 6,
#          'Music': 14,
#          'in': 19,
#          'Manager’s': 2,
#          'Procurement': 38,
#          'NodeJS': 16,
#          'Backend': 17,
#          'Writer': 39,
#          'Hardware': 9,
#          'SW': 3,
#          'KSA': 15,
#          'Performance': 15,
#          'Culture': 7,
#          'Internship': 49,
#          '(Software)': 6,
#          'Part': 13,
#          'Time': 23,
#          'Females': 24,
#          'Only': 28,
#          'RPA': 17,
#          'Export': 16,
#          '-GE-RS': 2,
#          'Math': 23,
#          'Preparatory)': 3,
#          'ASP.NET': 17,
#          'B2B': 14,
#          'Mansoura': 21,
#          'Adviser': 8,
#          "''Females": 1,
#          "Only''": 1,
#          'Community': 7,
#          'FrontEnd': 9,
#          '(jQuery)': 3,
#          'And': 33,
#          '(For': 5,
#          'SUE)': 2,
#          'Background': 4,
#          '"Laravel': 7,
#          'Project"': 7,
#          'Estimation': 3,
#          'UI': 35,
#          'Design': 45,
#          'intern': 1,
#          '@': 1,
#          'Addicta': 1,
#          'UX/UI': 20,
#          'Programmer': 3,
#          'Monitoring': 3,
#          'Data': 93,
#          'ETL': 16,
#          'Regulatory': 3,
#          'Compliance': 2,
#          'Delta': 9,
#          'System': 156,
#          'Enterprise': 18,
#          '–': 28,
#          'Industrial': 7,
#          'Automation': 40,
#          'Core': 18,
#          'REST': 8,
#          'to': 16,
#          'GraphQL': 8,
#          'SQL': 27,
#          'Server': 21,
#          'Secondary': 2,
#          'Production': 59,
#          'Instructional': 9,
#          'Copy': 13,
#          'Hospital': 9,
#          'Montessori': 11,
#          'Functional': 19,
#          'Corporate': 25,
#          'BI/BW': 1,
#          'Native': 56,
#          'Foundation;': 2,
#          'Stage': 10,
#          '1': 3,
#          'Class': 17,
#          'Architect': 49,
#          'Telemarketing': 30,
#          'LC': 3,
#          'Systems': 29,
#          '(A/V,': 1,
#          'PA,': 1,
#          'IPTV)': 1,
#          'Tanta': 23,
#          'Media/Digital': 1,
#          'Art': 31,
#          'Fresh': 12,
#          'RFID': 2,
#          'Care': 25,
#          'Section': 33,
#          'Head': 70,
#          'Primary': 31,
#          'Structural': 11,
#          'Shop': 1,
#          'Drawing': 2,
#          'Ionic': 16,
#          'App': 28,
#          'Current': 11,
#          'Hurghada': 16,
#          'BackEnd': 7,
#          'Egypt': 21,
#          '(Ionic': 2,
#          'Flutter)': 2,
#          'Node.JS': 10,
#          'Fullstack': 4,
#          'Public': 35,
#          'Relations': 45,
#          'Human': 23,
#          'Resources': 21,
#          'MS': 9,
#          'Dynamics': 21,
#          'Tourism': 4,
#          'Microsoft': 25,
#          '365/AX': 6,
#          'Contact': 4,
#          'Center': 76,
#          'UAE': 12,
#          'National': 7,
#          'IKEA': 10,
#          'Dubai': 17,
#          'React': 60,
#          'Electromechanical': 5,
#          'Facilities': 11,
#          'Early': 1,
#          'Years': 1,
#          'Foreign': 19,
#          'Call': 50,
#          'EPM': 5,
#          'Representatives': 5,
#          '(Assiut)': 5,
#          'Copywriter': 27,
#          'Supply': 13,
#          'Chain': 11,
#          'CEO': 37,
#          'Visual': 6,
#          'Basic': 3,
#          'Communications': 12,
#          'Field': 12,
#          '(Light': 3,
#          'Current)': 3,
#          'Facility': 12,
#          'WasteWater': 2,
#          'Treatment': 2,
#          'Process': 5,
#          '(Night': 4,
#          'Shift)': 10,
#          '(Sales': 18,
#          'Outdoor)': 5,
#          'QA/QC': 9,
#          'Teaching': 7,
#          '[Kindergarten]': 3,
#          'SharePoint': 33,
#          'SAP': 48,
#          'FI-CO': 1,
#          'Cisco': 5,
#          'Integration': 17,
#          'Solution': 28,
#          'UCCE': 1,
#          '(Freelance)': 1,
#          'Local': 12,
#          'ASP.Net': 7,
#          'IOS': 19,
#          '(for': 1,
#          'Advisor': 38,
#          'Co-Teacher/Heliopolis': 3,
#          'Of': 28,
#          'Archives': 4,
#          'Information': 16,
#          'General': 38,
#          'iOS/Android': 3,
#          'Secretary/Administrator': 1,
#          '(Flutter)': 5,
#          '(Paint)': 2,
#          'Commercial': 16,
#          'Cross-Platform': 5,
#          'Developer/Programmer': 5,
#          'Onboarding': 5,
#          '"Trainee"': 5,
#          'Brazil': 9,
#          'Implementation': 28,
#          'Serviceability': 1,
#          'Blockchain': 3,
#          '(Agile/Software/UX/Analysis)': 2,
#          'Node.js': 27,
#          'Motion': 21,
#          'Trainer': 19,
#          'Oman': 6,
#          'Mean': 20,
#          '(E-Pharmacy)': 6,
#          'Entry': 23,
#          'Animator': 7,
#          'Collection': 4,
#          '/Social': 2,
#          'Architectural': 16,
#          '(Application': 3,
#          'Support)': 3,
#          'BE': 3,
#          'Plumbing': 3,
#          'Fire': 13,
#          'Fighting': 7,
#          '(Events': 6,
#          'Management)': 8,
#          'Activity': 1,
#          'Foreigner': 1,
#          'Web/Graphic': 2,
#          '(CHS)2020': 6,
#          'WebMethods': 2,
#          'Saudi': 24,
#          'Arabia': 24,
#          '(PHP/Laravel)': 5,
#          'PE': 6,
#          'Pre-sales': 9,
#          '(React-Native)': 3,
#          'IT/Software': 2,
#          'Aluminum': 3,
#          'Works': 4,
#          'Building': 3,
#          'Fundraising': 3,
#          'Accounting': 27,
#          'FileNet/Java': 5,
#          'Mohandessin': 8,
#          'Branch': 15,
#          'Factory': 3,
#          '(C#/MVC)': 4,
#          'Soft': 2,
#          'Skills': 2,
#          'Alex': 6,
#          'Youtuber': 4,
#          'Projects': 7,
#          'High': 3,
#          'MEP': 13,
#          '(B2B': 8,
#          'Proofreader': 4,
#          'Direct': 10,
#          'Ledger': 1,
#          'Helpdesk': 1,
#          'HSE': 11,
#          'Strategist': 12,
#          'WINTER': 3,
#          '2020|Shape': 3,
#          'Ukraine': 5,
#          'Dokki': 14,
#          'SCRUM': 2,
#          'Master': 34,
#          'VPN': 3,
#          'Network': 82,
#          'Documents': 2,
#          'C++': 8,
#          'Applications': 11,
#          'Assurance': 19,
#          'For': 34,
#          'Banking': 13,
#          'Senior.NET': 5,
#          'Benha': 2,
#          'Dynamic': 4,
#          '365': 4,
#          'Science': 27,
#          'Fusion': 1,
#          'Recruiter': 11,
#          '(SD3)': 3,
#          '(Automotive)': 1,
#          'Manager/Scrum': 3,
#          'Deputy': 5,
#          'Affairs': 8,
#          'Payable': 13,
#          'Draftsman': 4,
#          'Sr.': 31,
#          '(Restaurant': 1,
#          'Software)': 8,
#          '(Shower': 2,
#          'Cabin': 2,
#          'Sanitary': 2,
#          'Ware': 9,
#          'Bathtub)': 2,
#          'HCM': 7,
#          'MIS': 3,
#          '(Content': 2,
#          'مسئول': 8,
#          'إداري': 5,
#          'E-Learning': 5,
#          'Visualizer/': 2,
#          'DevOps': 37,
#          'Support-Gold': 1,
#          'WE': 1,
#          'Incident': 3,
#          'Sheikh': 3,
#          'Zayed': 3,
#          'Primavera': 2,
#          'P6': 2,
#          'Textile': 12,
#          'Dyes': 3,
#          'ADF': 7,
#          'Drupal': 9,
#          '(Part': 30,
#          'Time)': 27,
#          'Project-Based': 7,
#          'WFP': 6,
#          'at': 4,
#          'the': 4,
#          'ASU': 3,
#          '(Graduates': 7,
#          'only)': 8,
#          'Lubricant': 2,
#          'Procurement/Purchasing': 6,
#          '(Consultant)': 2,
#          'Handling': 7,
#          'GE/A.A': 52,
#          'Vue.js': 3,
#          'Alsadat': 3,
#          '(IT/Telecom)': 4,
#          'Temporary': 3,
#          'Buying': 7,
#          'Or': 4,
#          'Insurance': 9,
#          'Homeroom': 5,
#          'Foreigners': 3,
#          'CFO': 5,
#          'Qlikview': 2,
#          'Graphics': 13,
#          'Scientist': 12,
#          'CCTV': 3,
#          'Buzz)': 3,
#          '(.NET/SQL)': 4,
#          'Speaker': 35,
#          'Cross': 12,
#          'Platform': 12,
#          'Infrastructure': 28,
#          'EDI': 8,
#          'Alarm': 4,
#          'Unit': 2,
#          'Accountant/': 1,
#          'Contracting': 5,
#          'Liferay': 1,
#          'After': 6,
#          '(EMEA)': 2,
#          'Stages': 4,
#          'Success': 19,
#          '(E': 2,
#          'Pharmacy)': 2,
#          'Cashier': 3,
#          'Automotive': 9,
#          'Cairo,': 4,
#          'BI': 35,
#          'Azure': 6,
#          'UI/User': 4,
#          'Interface': 4,
#          'APEX': 4,
#          'E-Payment': 3,
#          'Entrepreneur': 12,
#          'Turkey-GE': 3,
#          'Buyer': 15,
#          'Grade': 2,
#          '4': 2,
#          '(Males': 2,
#          'Only)': 3,
#          'Food': 2,
#          'Beverage': 1,
#          'Scrum': 28,
#          'Stores': 5,
#          'Host': 6,
#          '(Information': 6,
#          'Technology)': 6,
#          '/Alexandria': 4,
#          'Co-Teacher': 4,
#          'Turkey': 6,
#          'New': 10,
#          'Exterior': 3,
#          '(SaaS)': 7,
#          'Unified': 8,
#          '(Real': 5,
#          'Estate)': 7,
#          '5th': 2,
#          'Settlement': 2,
#          'Disk': 3,
#          'Cabling': 5,
#          'ASP': 7,
#          'Unity': 4,
#          'Tax': 1,
#          'Apps': 5,
#          'Buisness': 4,
#          'Salesmen': 2,
#          'BTL': 5,
#          'Agency': 7,
#          '(Angular)': 10,
#          'SSIS': 6,
#          'Night': 7,
#          'Shift': 11,
#          'Operation': 17,
#          'Coordination': 2,
#          'ABB': 2,
#          'Panels': 4,
#          'Drives': 1,
#          '(Alexandria)': 10,
#          'Creation': 5,
#          'Teachers': 4,
#          'Schools': 3,
#          'Dammam': 2,
#          '(Outdoor)': 5,
#          'Contracts': 8,
#          'Huawei': 3,
#          'Nurse': 3,
#          'Assiut': 10,
#          'Services': 13,
#          'Delivery': 7,
#          'Deployment': 1,
#          'Tunis': 1,
#          'UI-UX': 4,
#          'Wholesale': 2,
#          'Stack-PHP': 1,
#          'Beauty': 3,
#          'Clinic': 7,
#          'ACCOUNTANT': 1,
#          '(PHP)': 12,
#          'Installation': 10,
#          '(IT': 4,
#          'LV': 2,
#          'MV': 2,
#          '6th': 16,
#          'October': 17,
#          'Executives': 3,
#          '(CSE)': 3,
#          'Steel': 12,
#          'Detailing': 2,
#          '(Civil': 1,
#          'Architecture)': 1,
#          '(ECM)': 4,
#          'Indirect': 7,
#          'Hosting': 3,
#          'Warehouse': 18,
#          'ICT/': 3,
#          '(Cairo': 2,
#          'Region)': 5,
#          'Business/System': 2,
#          'Tendering': 11,
#          'Physics': 9,
#          'Banha': 6,
#          '(Personnel)': 7,
#          '(IOT': 2,
#          'Department)': 2,
#          'Category': 9,
#          '(Alexandria': 3,
#          '6': 4,
#          'Area': 15,
#          'Head,': 1,
#          'Oncology': 1,
#          'Emerging': 1,
#          'Markets': 4,
#          'Central': 5,
#          '(MENA)': 1,
#          'Training': 16,
#          'Centers': 1,
#          '"Microservices"': 2,
#          'Ticketing': 1,
#          'CCIE': 9,
#          'Libya': 1,
#          'Legal': 6,
#          'الشئون': 3,
#          'القانونية': 3,
#          'Partnerships': 12,
#          'AngularJS': 8,
#          'Co-Teacher(Heliopolis)': 4,
#          'Search': 7,
#          'Advertiser': 5,
#          'DBA': 15,
#          '(Database': 5,
#          'Admin)': 5,
#          'MENA': 1,
#          '(Microsoft.Net)': 5,
#          'Agents': 5,
#          'Full-time': 3,
#          'IELTS': 4,
#          'Prep.': 3,
#          'Heliopolis': 10,
#          'Logic': 3,
#          'Glass': 3,
#          'Fish': 3,
#          'Copywriter/Translator': 4,
#          'Sharepoint': 2,
#          'RiseUp-Tunisia': 3,
#          'Marketing-GE/A.A': 14,
#          'Fluent': 3,
#          'Retention': 1,
#          '(Telesales)': 1,
#          '(Laravel)': 5,
#          'Engineer/Specialist': 3,
#          'User': 2,
#          'Ikea': 2,
#          '(C#/ASP.NET)': 3,
#          'Acquisition': 9,
#          'Laravel': 36,
#          'Language': 26,
#          'City/Sheraton': 4,
#          'Kids': 7,
#          'TOEFL/IELTS': 1,
#          'Preschool': 14,
#          'مندوب': 7,
#          'مبيعات': 7,
#          'Xamarin': 2,
#          'Forms': 2,
#          'Oil': 6,
#          'Gas': 5,
#          'Internal': 16,
#          'Audit': 8,
#          'Demo': 3,
#          'Maker': 3,
#          'Mathematics': 7,
#          'Architecture': 14,
#          'Department': 8,
#          'Based': 2,
#          '(R&D)': 12,
#          'Node': 3,
#          'JS': 3,
#          'مدير': 4,
#          'انتاج': 2,
#          'في': 2,
#          'مجال': 2,
#          'الدعاية': 2,
#          'والاعلان': 2,
#          'BMS': 2,
#          'Complaint': 6,
#          'AX': 5,
#          'Government': 4,
#          'Relation': 5,
#          '(Techno': 2,
#          'Consultant)': 2,
#          'VPO': 6,
#          'Labeller': 1,
#          'German-Speaker': 1,
#          '(Cloud)': 3,
#          'Professeur': 3,
#          'De': 3,
#          'Français': 3,
#          'British': 10,
#          'Remote': 6,
#          'Sensing': 4,
#          'Credit': 8,
#          'Speakers': 3,
#          'RiseUp': 12,
#          '(Contrrol': 1,
#          'Assurance)': 1,
#          'Robotics/Arduino': 1,
#          '(Unified': 3,
#          'Communications)': 3,
#          'Offshore': 3,
#          'Year': 6,
#          '7': 7,
#          '(6th': 6,
#          'October)': 6,
#          'Embedded': 24,
#          'PCB': 4,
#          'Company)': 2,
#          '(Electrical/Mechanical)': 2,
#          'React-Native': 10,
#          'Passive': 2,
#          'Admission': 1,
#          'Registrar': 1,
#          'Retails': 4,
#          'Stack/': 1,
#          'Structure': 8,
#          "Teacher's": 3,
#          'Tele-Marketing': 2,
#          'Lighting': 6,
#          '-Technical': 5,
#          '(French': 5,
#          'Speaker)': 7,
#          '(Java': 2,
#          'Integration)': 2,
#          'Audience': 4,
#          'Jacquard': 1,
#          'Psychologist': 5,
#          'Respiratory': 2,
#          'Order': 5,
#          '/Project': 2,
#          'Ted': 2,
#          'Baker': 2,
#          '-Mall': 1,
#          'Chemicals': 2,
#          '(Inspector': 2,
#          'Safety)': 2,
#          'موظفة': 5,
#          'نشر': 5,
#          'و': 5,
#          'سوشيال': 5,
#          'ميديا': 5,
#          'اونلاين': 5,
#          'CMS': 2,
#          'Monufya': 15,
#          'BIM': 14,
#          'Discipline': 8,
#          'Desktop': 2,
#          'Operator': 7,
#          'YT': 2,
#          'Storekeeper': 14,
#          'leader': 3,
#          'Construction': 18,
#          'Matruh': 2,
#          'Analysis': 12,
#          'Servers': 1,
#          'Storage': 2,
#          'Instrumentation': 3,
#          'Abu': 5,
#          'Rawash': 4,
#          'Radio': 2,
#          'PHP/Laravel': 8,
#          'Communication': 15,
#          'Raw': 2,
#          'Material': 12,
#          'HR/Office': 4,
#          '(MEP)': 1,
#          'Chairman': 3,
#          'Tender': 2,
#          '(After': 5,
#          'Hours': 3,
#          'Engineer/Lead': 1,
#          'Asp': 2,
#          'Core/Angular': 2,
#          'AFGRE': 5,
#          'Python': 13,
#          'GRC': 4,
#          'Kickstart': 29,
#          '[Marketing]': 26,
#          'Writing-GE/A.A': 5,
#          'E-Commerce': 9,
#          'VR': 2,
#          'Positive': 3,
#          'Internship-': 7,
#          'Tunisia-': 9,
#          'Animation': 1,
#          'Resource': 2,
#          'Market': 7,
#          'Research': 11,
#          'Finishing': 5,
#          'Packaging': 2,
#          'Event': 3,
#          'Channel': 3,
#          '(Primary/Preparatory)': 2,
#          'Library': 3,
#          'Front-end': 5,
#          'React.JS': 7,
#          'Machine': 7,
#          'Learning': 19,
#          'developer': 1,
#          'خارجي': 5,
#          '.NET/Angular': 2,
#          'Organization': 7,
#          'Guess': 3,
#          '[Business': 10,
#          'Development]': 10,
#          'BD': 5,
#          'Executive-': 7,
#          'Inbound': 2,
#          'Instructors': 5,
#          'Bilingual': 2,
#          'Aviation': 2,
#          'Studies': 3,
#          '(React': 3,
#          'JS)': 2,
#          '(Angular': 7,
#          '2+)': 3,
#          'Inspection': 2,
#          '(Node.Js/Angular)': 5,
#          'RPA/Robotics': 4,
#          'IB': 5,
#          'KICKSTART': 28,
#          'Gunsberg-': 5,
#          'CNS': 1,
#          'ATM': 1,
#          'Urban': 3,
#          'Landscape': 5,
#          'IGCSE': 2,
#          'Section)': 2,
#          'Factor': 7,
#          'Chef': 4,
#          'MERN': 4,
#          '(Windows)': 13,
#          'Film': 2,
#          'Extrusion': 2,
#          'line': 2,
#          'YouTube': 2,
#          'Radiology': 6,
#          'Technician': 20,
#          'Shipping': 2,
#          '(Office': 6,
#          'Furniture)': 2,
#          '[Sales': 2,
#          'A': 2,
#          'Marketing]': 2,
#          'Photographer': 5,
#          'Videographer': 3,
#          'Rise': 9,
#          'UP': 9,
#          'Creator-GE/A.A': 3,
#          '3rd': 3,
#          'Back-end': 3,
#          'BW': 5,
#          'ICT': 7,
#          'MM': 1,
#          'Auditor': 10,
#          'Growth': 4,
#          '(Hotel)': 2,
#          'OD': 8,
#          'Development-GE/A.A': 4,
#          'PR': 4,
#          'Marks': 2,
#          'Spencer': 2,
#          'Dandy': 2,
#          'Infrastructural': 1,
#          '(Leading': 2,
#          'Branch)': 2,
#          'Experience': 2,
#          'Regional': 8,
#          'Planner': 8,
#          'Supervision': 1,
#          'Narrator': 1,
#          'Mathematical': 1,
#          'Videos': 1,
#          'Intern-': 2,
#          'BI/Cognos': 3,
#          'Little': 1,
#          '(Advertising)': 9,
#          'PPC': 1,
#          'Remotely': 17,
#          'Geospatial': 2,
#          'Middleware': 1,
#          'ABAP': 14,
#          'Continuous': 2,
#          'Improvement': 2,
#          '(Linux)': 7,
#          '(Tester)': 1,
#          ...})

# %% [markdown]
# we see that the `title` coiumn has many charachers and words that should be cleaned before feeding this data to the model.
# <br><br>
# we suggest to remove **punctuations** and **numbers** from the title column since it would not have a critical value in our model. then we can **lowercase** all the string so that the model doesn't differentiate between a word like '*Developer*' and '*developer*'

# %%
import string

def normalize(title):
  # remove punctuation
  replace_punctuation = str.maketrans(string.punctuation, ' '*len(string.punctuation))
  title = title.translate(replace_punctuation)
  # remove numbers
  title = re.sub('\d', ' ', title)
  # lowercase all characters
  title = title.lower()
  # remove extra spaces between string
  title = ' '.join(title.split())

  return title

# %%
print('before applying normalizaitoin: \n')
print(dataset['title'][:20])

# apply the normalization to the title column
normalized_titles = [normalize(title) for title in dataset['title']]

print('\n after applying normalizaitoin: \n')
print(normalized_titles[:20])
# Out:
# before applying normalizaitoin:
#
# 0                           Full Stack PHP Developer
# 1            CISCO Collaboration Specialist Engineer
# 2                      Senior Back End-PHP Developer
# 3                                        UX Designer
# 4                                Java Technical Lead
# 5                         Technical Support Engineer
# 6                               Senior iOS Developer
# 7                                Mechanical Engineer
# 8     Real Estate Sales Specialist - 10th of Ramadan
# 9                                   School Principal
# 10                       Senior Sales Representative
# 11                                        Accountant
# 12                            Indoor Sales Executive
# 13                    PHP Full-Stack - Joomla Expert
# 14                         English Teacher Assistant
# 15                             Marketing Coordinator
# 16                         Senior Business Developer
# 17                          Senior Website Developer
# 18                                  Chief Accountant
# 19                        Senior Front-End Developer
# Name: title, dtype: object
#
#  after applying normalizaitoin:
#
# ['full stack php developer', 'cisco collaboration specialist engineer', 'senior back end php developer', 'ux designer', 'java technical lead', 'technical support engineer', 'senior ios developer', 'mechanical engineer', 'real estate sales specialist th of ramadan', 'school principal', 'senior sales representative', 'accountant', 'indoor sales executive', 'php full stack joomla expert', 'english teacher assistant', 'marketing coordinator', 'senior business developer', 'senior website developer', 'chief accountant', 'senior front end developer']

# %% [markdown]
# The next step we want to know if this model is *balanced* (number of observation in the dataset is approximately the same for each class) or not. <br>
# lets get insight about our labels `jobFunctions`

# %%
Counter(job_functions_flattened)
# Out:
# Counter({'Accounting/Finance': 477,
#          'Administration': 656,
#          'Analyst/Research': 272,
#          'Banking': 10,
#          'Business Development': 445,
#          'C-Level Executive/GM/Director': 3,
#          'Creative/Design/Art': 739,
#          'Customer Service/Support': 863,
#          'Education/Teaching': 527,
#          'Engineering - Construction/Civil/Architecture': 302,
#          'Engineering - Mechanical/Electrical': 499,
#          'Engineering - Oil & Gas/Energy': 10,
#          'Engineering - Other': 169,
#          'Engineering - Telecom/Technology': 3886,
#          'Fashion': 3,
#          'Hospitality/Hotels/Food Services': 15,
#          'Human Resources': 260,
#          'IT/Software Development': 4383,
#          'Installation/Maintenance/Repair': 576,
#          'Legal': 21,
#          'Logistics/Supply Chain': 171,
#          'Manufacturing/Production': 122,
#          'Marketing/PR/Advertising': 1400,
#          'Media/Journalism/Publishing': 951,
#          'Medical/Healthcare': 217,
#          'Operations/Management': 314,
#          'Pharmaceutical': 129,
#          'Project/Program Management': 308,
#          'Purchasing/Procurement': 140,
#          'Quality': 404,
#          'R&D/Science': 119,
#          'Sales/Retail': 1802,
#          'Sports and Leisure': 7,
#          'Strategy/Consulting': 17,
#          'Tourism/Travel': 10,
#          'Training/Instructor': 135,
#          'Writing/Editorial': 202})

# %% [markdown]
# we see that our dataset is **imbalanced** (one class has 4383 record and another one has only 7 !!) and this may cause some problems in our model. so we should take care about this issue. since there are many machine learning algorithms that fails with imbalanced data and many metrics also doesn't provide correct insights about the error with imbalanced data. based on this point *we should choose the right algorithm and the right metric for this data!*
# <br><br>
# But now how should we overcome this problem? We can consider **downsampling** the majority class or **upsampling** the minority class. But because we don't have a large dataset I think the simplest and best one in our situation is  '*upsampling*' which means to get more data about minority classes. this will make every class has approximately the same observations as the other classes and this will be very benificial to our model so that it can't be biased to a particular class.
#  <br><br>
# Another solution we may try with our problem in the **feature engineering** part is to merge some labels that is quite similar to each others into one label. this will improve our model significantly!

# %% [markdown]
# # Vectorize your data

# %% [markdown]
# Unfortunately our machine learning model will not understand these categorical data even after cleaning it. it expects the input as numbers not characters and words. so what can we do?
# <br>
# we will convert these words into vectors of numbers then feed it to the algorithm. we can use many techniques such as [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) or [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html). both of them tokenize a collection of text and build a Word counts but I prefer `TfidfVectorizer` because it also penalize worthless words like 'the' that may appear many times in the data.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Here we will build a `TfidfVectorizer` with n-gram in a range from 1 to 3. this means that the algorithm creates a window from one word to 3 words and passes it around each title to detect the correlations between these words and the order of them in the windows. and finally it will return a sparse matrix that carries the features of all these words with the correlations between each others and the order of them.

# %%
# build Tfidf with n-gram of 1 to 3 words
vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,3))
feature_matrix = vectorizer.fit_transform(normalized_titles)

# %% [markdown]
# Also we should vectorize the labels and since our model has multilabel (*title may has more than one function*) we should use [MultiLabelBinarizer](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html)
# . It will return a matrix of zeros and ones. for each row the index of the true label is one and the others are zeros.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

multiLabelBinarizer = MultiLabelBinarizer()
labels = multiLabelBinarizer.fit_transform(job_functions)

# %% [markdown]
# # Build the model

# %% [markdown]
# Well! lets start a new part and train a simple model with our data. we will try to train [multiOutputClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html). This is a simple strategy for extending classifiers that do not natively support *multi-target classification*.
# <br> And we will try to train the model with (**SVC**) Support Vector  Classifier which works fine on sparse and *unbalanced data*.

# %%
from sklearn.svm import LinearSVC 
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(feature_matrix, labels, test_size=0.2)
estimator = LinearSVC()
model = MultiOutputClassifier(estimator)
model.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=LinearSVC(C=1.0, class_weight=None, dual=True,
#                                           fit_intercept=True,
#                                           intercept_scaling=1,
#                                           loss='squared_hinge', max_iter=1000,
#                                           multi_class='ovr', penalty='l2',
#                                           random_state=None, tol=0.0001,
#                                           verbose=0),
#                       n_jobs=None)

# %% [markdown]
# After we tained the model we want to see how the model works on the test set. You can do it directly with a **predict** function.

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluate your model

# %% [markdown]
# Our data is imbalanced so choosing a good metric will boost the performance of the model significantly. We will try **F-1 score** because it’s one of the best metrics to use with imbalanced data. It’s simply the harmonic mean of *precision* and *recall*. And when it reaches a high score, that means that we reached a perfect precision and recall together.

# %%
from sklearn.metrics import f1_score

f1_score(y_test, y_pred, average='weighted')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# 0.911731906663528

# %% [markdown]
# #Test your own

# %% [markdown]
# You can try this model by entering an employee's **job title** and our model will recommend new **job functions** !!

# %%
def recommend_job_functions(title):
  '''
  This function recommend new job functions based on the employee job title
  '''
  title_norm = normalize(title)
  title_vec = vectorizer.transform([title_norm])
  pred = model.predict(title_vec)
  
  # return job functions from the prediction
  results = []
  for index in np.where(pred[0]==1)[0]:
    results.append(classes[index])

  return results

# %%
title = 'machine learning engineer'
functions = recommend_job_functions(title)
print('Recommended functions based on this title: \n', functions)
# Out:
# Recommended functions based on this title:
#  ['Media/Journalism/Publishing', 'Administration', 'Operations/Management']

# %% [markdown]
# # saving the model using `pickle`

# %% [markdown]
# Finally after we built the model, we want to save it to a file on the desk in order to load it by flask app. we recommend using `pickle`. it's a python module used for **serializing** and **de-serializing** a python object structure. Pickling is a way to convert a python object (list, dict, etc.) into a character stream. The idea is that this character stream contains all the information necessary to reconstruct the object in another python script.<br>
# So in our situation we will pickle `model`, `vectorizer` and `classes` objects so that we can de-serialize and use them in the flask app.

# %% [markdown]
# To pickle an object in python. you should use `pickle.dump()` and pass to it the file path you want to dump (with `'wb'` mode)

# %%
import pickle

pickle.dump(model, open('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/model.pkl', 'wb'))
pickle.dump(vectorizer, open('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/vectorizer.pkl', 'wb'))
pickle.dump(classes, open('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/classes.pkl', 'wb'))

# %% [markdown]
# In order to use them in flask app. All you need is to use `pickle.load()` with your pickle file in your path. don't forget to use `'rb'` mode while loading.

# %%
model = pickle.load(open('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/model.pkl', 'rb'))
vectorizer = pickle.load(open('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/vectorizer.pkl', 'rb'))
classes = pickle.load(open('/gdrive/My Drive/MohamedAbdullah_JobFunctionRecommendationTask/01_Code/classes.pkl', 'rb'))
